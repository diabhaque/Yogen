# %%
import warnings

import numpy as np
import pandas as pd

from jre_utils.datapath import (
    factor_data_paths,
    model_built_data_paths,
    get_derived_csv_path,
    get_derived_lpa_path,
    get_derived_plps_path,
)

warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", None)

# %%
asset_type = "building"
years_ahead = 2

metrics = {
    "weighted_mean": "unit_price_wmean",
    "weighted_median": "unit_price_wmedian",
    "mean": "unit_price_mean",
    "median": "unit_price_median",
    "weighted_mean_smoothed": "unit_price_wmean_smoothed",
    "weighted_median_smoothed": "unit_price_wmedian_smoothed",
    "mean_smoothed": "unit_price_mean_smoothed",
    "median_smoothed": "unit_price_median_smoothed",
}

dataset_paths = {
    "transactions": get_derived_csv_path(asset_type),
    "lpa": get_derived_lpa_path(),
    "plps": get_derived_plps_path()
}

granularity_columns = ["area", "area_code"]
group_by_columns = granularity_columns + ["year"]
display_columns = ["unit_price", "total_traded_area", "count"]

metric_key = "median"
metric = metrics[metric_key]

metric_pct_chg = metric + "_pct_chg"
upcoming_metric = "upcoming_" + metric

# %%
dataset_key = "transactions"
core_path = dataset_paths[dataset_key]
population_path = factor_data_paths["processed"]["population"]["municipality"]
migration_path = factor_data_paths["processed"]["migration"]["municipality"]
taxable_income_path = factor_data_paths["processed"]["taxable_income"]["municipality"]
new_dwellings_path = factor_data_paths["processed"]["new_dwellings"]["municipality"]
lfs_revenue_path = factor_data_paths["processed"]["lfs_revenue_breakdown"]["municipality"]

dataset_name = f"sequence_{dataset_key}_{asset_type}_{metric_key}_{years_ahead}"
model_built_data_path = model_built_data_paths[dataset_name]

# %%
df = pd.read_csv(core_path)
df = df.assign(asset_type=asset_type)

population_df = pd.read_csv(population_path)
migration_df = pd.read_csv(migration_path)
taxable_income_df = pd.read_csv(taxable_income_path)
new_dwellings_df = pd.read_csv(new_dwellings_path)
lfs_revenue_df= pd.read_csv(lfs_revenue_path)

df = (
    df.merge(population_df, on=group_by_columns, how="left")
    .merge(migration_df, on=group_by_columns, how="left")
    .merge(taxable_income_df, on=group_by_columns, how="left")
    .merge(new_dwellings_df, on=group_by_columns, how="left")
    .merge(lfs_revenue_df, on=group_by_columns, how="left")
)

# %%
# prepare metrics
df = df.sort_values(by=group_by_columns, ascending=True)
df[metric_pct_chg] = df.groupby(granularity_columns)[metric].pct_change(periods=years_ahead)
# df = df[~df[metric_pct_chg].isna()] # I don't want to drop the data from the first two years. I.e. 2007 should have 2005 and 2006 data in it's window

# %%
# prepare additional factors
df["count_growth"] = df.groupby(granularity_columns)["count"].pct_change()
df["yearly_price_growth"] = df.groupby(granularity_columns)[metric].pct_change()

for column in ["count", "total_traded_area", metric]:
    df[f"{column}_log"] = df[column].apply(lambda x: np.log10(1 + x))
    df[f"{column}_log_normalized_yearly"] = df.groupby("year")[f"{column}_log"].transform(
        lambda x: (x - x.mean()) / x.std()
    )

for column in ["count_growth", "yearly_price_growth", metric_pct_chg]: # metric_pct_chg_normalized_yearly will be the key metric
    df[f"{column}_normalized_yearly"] = df.groupby("year")[column].transform(
        lambda x: (x - x.mean()) / x.std()
    )

# %%
df["migrations_is_available"] = df["net_migration_ratio"].notnull().astype(int)
df["taxable_income_is_available"] = df["taxable_income"].notnull().astype(int)
df["total_tax_is_available"] = df["total_tax"].notnull().astype(int)
df["dwellings_is_available"] = df["new_dwellings"].notnull().astype(int)
df["metric_pct_chg_is_available"] = df[metric_pct_chg].notnull().astype(int)

# %%
log_normalize_columns = [
    metric,
    "count",
    "total_traded_area",
    "in_migrations",
    "out_migrations",
    "population",
    "taxpayer_count",
    "taxable_income",
    "taxable_income_per_taxpayer",
    "total_tax",
    "new_dwellings",
    "existing_dwellings",
]

normalize_columns = [
    metric_pct_chg,
    "count_growth",
    "yearly_price_growth",
    "total_tax_growth",
    "taxable_income_growth",
    "taxable_income_per_taxpayer_growth",
    "net_migration_ratio",
    "new_dwellings_ratio",
    "taxpayer_count_growth",
]

maintain_columns = [
    "migrations_is_available",
    "taxable_income_is_available",
    "dwellings_is_available",
    "total_tax_is_available",
    "metric_pct_chg_is_available"
]

id_columns = ["area_code", "area", "year", "asset_type"]

feature_columns = (
    [f"{column}_log_normalized_yearly" for column in log_normalize_columns]
    + [f"{column}_normalized_yearly" for column in normalize_columns]
    + maintain_columns
)

final_columns = id_columns + normalize_columns + log_normalize_columns + feature_columns

# add ratios and growths if necessary

df = df[final_columns]

# %%
df.to_csv(model_built_data_path, index=False)

# %%
df[df[metric_pct_chg] > 2]
# Out:
#        area_code                                 area  year asset_type  \
# 14196       5213              Akita-ken Kitaakita-shi  2017   building
# 14240       5348                 Akita-ken Mitane-cho  2013   building
# 14244       5348                 Akita-ken Mitane-cho  2017   building
# 14247       5348                 Akita-ken Mitane-cho  2020   building
# 14209       5214                 Akita-ken Nikaho-shi  2014   building
# ...          ...                                  ...   ...        ...
# 16715      35344              Yamaguchi-ken Hirao-cho  2016   building
# 16680      35305          Yamaguchi-ken Suooshima-cho  2011   building
# 10948      19430  Yamanashi-ken Fujikawaguchiko-machi  2018   building
# 10862      19365             Yamanashi-ken Minobu-cho  2010   building
# 10827      19212           Yamanashi-ken Uenohara-shi  2022   building
#
#        unit_price_median_pct_chg  count_growth  yearly_price_growth  \
# 14196                   2.170899     -0.133333             0.064516
# 14240                   2.020581      0.428571            -0.445209
# 14244                   2.500000     -0.166667             0.008333
# 14247                   2.504248      1.000000             0.353846
# 14209                   2.822222     -0.476190             0.107692
# ...                          ...           ...                  ...
# 16715                   3.724571     -0.111111             1.147532
# 16680                   5.327160      0.230769             0.637153
# 10948                   2.221477      0.235294             0.784615
# 10862                   2.329198      0.000000             2.080750
# 10827                   2.021667      0.444444            -0.363000
#
#        total_tax_growth  taxable_income_growth  \
# 14196          0.008246               0.010451
# 14240          0.014836               0.012179
# 14244          0.013645               0.024080
# 14247          0.019286               0.022819
# 14209         -0.069959              -0.037986
# ...                 ...                    ...
# 16715          0.027842               0.005355
# 16680         -0.007041              -0.020291
# 10948          0.016303               0.032696
# 10862         -0.058103              -0.055232
# 10827          0.001070                    NaN
#
#        taxable_income_per_taxpayer_growth  net_migration_ratio  \
# 14196                            0.005560            -0.003979
# 14240                            0.007761            -0.008292
# 14244                            0.006214            -0.004929
# 14247                            0.020381            -0.009506
# 14209                            0.002243            -0.009690
# ...                                   ...                  ...
# 16715                            0.012612            -0.003527
# 16680                           -0.009063            -0.000526
# 10948                            0.014187            -0.003867
# 10862                           -0.026459            -0.011270
# 10827                                 NaN            -0.005194
#
#        new_dwellings_ratio  taxpayer_count_growth  unit_price_median  count  \
# 14196             0.007335               0.004864       22580.645161   13.0
# 14240                  NaN               0.004385        7628.378378   10.0
# 14244                  NaN               0.017756       11000.000000    5.0
# 14247                  NaN               0.002390        8461.538462    6.0
# 14209             0.006084              -0.040139       53333.333333   11.0
# ...                    ...                    ...                ...    ...
# 16715                  NaN              -0.007166       45428.571429    8.0
# 16680                  NaN              -0.011331       28472.222222   16.0
# 10948                  NaN               0.018250       80000.000000   21.0
# 10862                  NaN              -0.029555       51602.564103    4.0
# 10827                  NaN                    NaN       49000.000000   13.0
#
#        total_traded_area  in_migrations  out_migrations  population  \
# 14196             3975.0          564.0           686.0     30662.0
# 14240             7980.0          295.0           429.0     16160.0
# 14244             2840.0          256.0           333.0     15622.0
# 14247             4900.0          203.0           348.0     15254.0
# 14209             2250.0          402.0           640.0     24562.0
# ...                  ...            ...             ...         ...
# 16715             1810.0          402.0           445.0     12191.0
# 16680             5525.0          568.0           576.0     15210.0
# 10948             8740.0         1014.0          1115.0     26118.0
# 10862             1255.0          285.0           425.0     12422.0
# 10827             4790.0          472.0           589.0     22525.0
#
#        taxpayer_count  taxable_income  taxable_income_per_taxpayer  total_tax  \
# 14196         12188.0      28675802.0                  2352.789793  3033280.0
# 14240          6414.0      14366071.0                  2239.799033  1421726.0
# 14244          6305.0      14607327.0                  2316.784615  1420961.0
# 14247          6292.0      15076577.0                  2396.150191  1487683.0
# 14209         10498.0      27126886.0                  2584.005144  2722969.0
# ...               ...             ...                          ...        ...
# 16715          5126.0      13389313.0                  2612.039212  1291046.0
# 16680          6108.0      15121424.0                  2475.675180  1388885.0
# 10948         12163.0      40365841.0                  3318.740525  4501474.0
# 10862          5976.0      15362432.0                  2570.688086  1483002.0
# 10827             NaN             NaN                          NaN  3132993.0
#
#        new_dwellings  existing_dwellings  \
# 14196          101.0             13769.0
# 14240            NaN                 NaN
# 14244            NaN                 NaN
# 14247            NaN                 NaN
# 14209           59.0              9697.0
# ...              ...                 ...
# 16715            NaN                 NaN
# 16680            NaN                 NaN
# 10948            NaN                 NaN
# 10862            NaN                 NaN
# 10827            NaN                 NaN
#
#        unit_price_median_log_normalized_yearly  count_log_normalized_yearly  \
# 14196                                -0.798307                    -0.931783
# 14240                                -1.909683                    -1.161654
# 14244                                -1.462121                    -1.650010
# 14247                                -1.651641                    -1.561653
# 14209                                 0.014544                    -1.014909
# ...                                        ...                          ...
# 16715                                -0.165429                    -1.291380
# 16680                                -0.652745                    -0.657964
# 10948                                 0.377283                    -0.541199
# 10862                                -0.076921                    -1.775275
# 10827                                -0.062303                    -0.983639
#
#        total_traded_area_log_normalized_yearly  \
# 14196                                -1.048143
# 14240                                -0.417941
# 14244                                -1.363378
# 14247                                -0.928934
# 14209                                -1.542576
# ...                                        ...
# 16715                                -1.753654
# 16680                                -0.599596
# 10948                                -0.292757
# 10862                                -2.113083
# 10827                                -0.936245
#
#        in_migrations_log_normalized_yearly  \
# 14196                            -0.250368
# 14240                            -0.685505
# 14244                            -0.726268
# 14247                            -0.823223
# 14209                            -0.476053
# ...                                    ...
# 16715                            -0.465720
# 16680                            -0.301978
# 10948                             0.109990
# 10862                            -0.745416
# 10827                            -0.307533
#
#        out_migrations_log_normalized_yearly  population_log_normalized_yearly  \
# 14196                             -0.222997                          0.083924
# 14240                             -0.565427                         -0.339633
# 14244                             -0.686725                         -0.349630
# 14247                             -0.622229                         -0.355200
# 14209                             -0.283683                         -0.065805
# ...                                     ...                               ...
# 16715                             -0.505544                         -0.512126
# 16680                             -0.379348                         -0.382494
# 10948                              0.092005                         -0.016895
# 10862                             -0.584604                         -0.515255
# 10827                             -0.259439                         -0.102090
#
#        taxpayer_count_log_normalized_yearly  \
# 14196                              0.133196
# 14240                             -0.267853
# 14244                             -0.288386
# 14247                             -0.291762
# 14209                              0.050086
# ...                                     ...
# 16715                             -0.416436
# 16680                             -0.296671
# 10948                              0.128128
# 10862                             -0.312973
# 10827                                   NaN
#
#        taxable_income_log_normalized_yearly  \
# 14196                              0.017366
# 14240                             -0.370607
# 14244                             -0.391640
# 14247                             -0.384812
# 14209                              0.012038
# ...                                     ...
# 16715                             -0.435444
# 16680                             -0.340576
# 10948                              0.214256
# 10862                             -0.334063
# 10827                                   NaN
#
#        taxable_income_per_taxpayer_log_normalized_yearly  \
# 14196                                          -1.146395
# 14240                                          -1.285163
# 14244                                          -1.244704
# 14247                                          -1.160684
# 14209                                          -0.366725
# ...                                                  ...
# 16715                                          -0.431441
# 16680                                          -0.653452
# 10948                                           0.968195
# 10862                                          -0.408910
# 10827                                                NaN
#
#        total_tax_log_normalized_yearly  new_dwellings_log_normalized_yearly  \
# 14196                         0.007316                            -1.262146
# 14240                        -0.440985                                  NaN
# 14244                        -0.466044                                  NaN
# 14247                         0.780308                                  NaN
# 14209                        -0.044556                            -1.693934
# ...                                ...                                  ...
# 16715                        -0.514417                                  NaN
# 16680                        -0.454415                                  NaN
# 10948                         0.249018                                  NaN
# 10862                        -0.417119                                  NaN
# 10827                         0.868983                                  NaN
#
#        existing_dwellings_log_normalized_yearly  \
# 14196                                 -1.192543
# 14240                                       NaN
# 14244                                       NaN
# 14247                                       NaN
# 14209                                 -1.534663
# ...                                         ...
# 16715                                       NaN
# 16680                                       NaN
# 10948                                       NaN
# 10862                                       NaN
# 10827                                       NaN
#
#        unit_price_median_pct_chg_normalized_yearly  \
# 14196                                     3.348990
# 14240                                     4.194427
# 14244                                     3.883714
# 14247                                     3.827987
# 14209                                     5.977968
# ...                                            ...
# 16715                                     4.939348
# 16680                                    11.941942
# 10948                                     3.944391
# 10862                                     4.720294
# 10827                                     3.176849
#
#        count_growth_normalized_yearly  yearly_price_growth_normalized_yearly  \
# 14196                       -0.501146                              -0.025278
# 14240                        0.665893                              -1.090658
# 14244                       -0.587525                              -0.133016
# 14247                        1.866983                               0.332083
# 14209                       -1.293966                               0.112112
# ...                               ...                                    ...
# 16715                       -0.419747                               2.089844
# 16680                        0.739070                               1.381713
# 10948                        0.521686                               0.321846
# 10862                       -0.324285                               3.987921
# 10827                        1.405231                              -0.771463
#
#        total_tax_growth_normalized_yearly  \
# 14196                           -0.002860
# 14240                            0.171774
# 14244                            0.175217
# 14247                            0.598651
# 14209                           -2.200680
# ...                                   ...
# 16715                            0.707632
# 16680                           -0.147184
# 10948                            0.452285
# 10862                           -1.380701
# 10827                           -0.468601
#
#        taxable_income_growth_normalized_yearly  \
# 14196                                -0.152912
# 14240                                 0.144822
# 14244                                 0.153589
# 14247                                 0.440240
# 14209                                -0.908857
# ...                                        ...
# 16715                                -0.555945
# 16680                                -0.508282
# 10948                                 0.302427
# 10862                                 0.253979
# 10827                                      NaN
#
#        taxable_income_per_taxpayer_growth_normalized_yearly  \
# 14196                                          -0.080740
# 14240                                           0.382134
# 14244                                          -0.063085
# 14247                                           0.452039
# 14209                                          -0.182576
# ...                                                  ...
# 16715                                           0.040003
# 16680                                          -0.355077
# 10948                                           0.050923
# 10862                                           0.312021
# 10827                                                NaN
#
#        net_migration_ratio_normalized_yearly  \
# 14196                              -0.056440
# 14240                              -0.590778
# 14244                              -0.166674
# 14247                              -0.673120
# 14209                              -0.761150
# ...                                      ...
# 16715                              -0.029067
# 16680                               0.233321
# 10948                              -0.022316
# 10862                              -1.122612
# 10827                              -0.191697
#
#        new_dwellings_ratio_normalized_yearly  \
# 14196                              -0.985714
# 14240                                    NaN
# 14244                                    NaN
# 14247                                    NaN
# 14209                              -1.003640
# ...                                      ...
# 16715                                    NaN
# 16680                                    NaN
# 10948                                    NaN
# 10862                                    NaN
# 10827                                    NaN
#
#        taxpayer_count_growth_normalized_yearly  migrations_is_available  \
# 14196                                -0.162979                        1
# 14240                                -0.094910                        1
# 14244                                 0.396556                        1
# 14247                                 0.083555                        1
# 14209                                -1.783833                        1
# ...                                        ...                      ...
# 16715                                -1.128923                        1
# 16680                                -0.428517                        1
# 10948                                 0.633754                        1
# 10862                                 0.072997                        1
# 10827                                      NaN                        1
#
#        taxable_income_is_available  dwellings_is_available  \
# 14196                            1                       1
# 14240                            1                       0
# 14244                            1                       0
# 14247                            1                       0
# 14209                            1                       1
# ...                            ...                     ...
# 16715                            1                       0
# 16680                            1                       0
# 10948                            1                       0
# 10862                            1                       0
# 10827                            0                       0
#
#        total_tax_is_available  metric_pct_chg_is_available
# 14196                       1                            1
# 14240                       1                            1
# 14244                       1                            1
# 14247                       1                            1
# 14209                       1                            1
# ...                       ...                          ...
# 16715                       1                            1
# 16680                       1                            1
# 10948                       1                            1
# 10862                       1                            1
# 10827                       1                            1
#
# [163 rows x 51 columns]

# %%
df.describe()
# Out:
#           area_code          year  unit_price_median_pct_chg  count_growth  \
# count  18075.000000  18075.000000               15783.000000  16929.000000
# mean   21787.703513   2014.585007                   0.070466      0.086552
# std    13211.069222      4.571298                   0.563051      0.406933
# min     1100.000000   2005.000000                  -0.949597     -0.855556
# 25%    11232.000000   2011.000000                  -0.180953     -0.145833
# 50%    21213.000000   2015.000000                  -0.009031      0.014599
# 75%    31390.000000   2019.000000                   0.171553      0.226667
# max    47362.000000   2022.000000                  11.688172      5.000000
#
#        yearly_price_growth  total_tax_growth  taxable_income_growth  \
# count         16929.000000      17991.000000           16945.000000
# mean              0.076275          0.006348               0.003242
# std               0.729590          0.049969               0.037483
# min              -0.933269         -0.677251              -0.400215
# 25%              -0.159016         -0.013625              -0.009775
# 50%              -0.002491          0.003406               0.005998
# 75%               0.161170          0.020636               0.020190
# max              65.038314          2.199177               0.808115
#
#        taxable_income_per_taxpayer_growth  net_migration_ratio  \
# count                        16945.000000         18075.000000
# mean                             0.001076            -0.002510
# std                              0.028099             0.005959
# min                             -0.395675            -0.099818
# 25%                             -0.008754            -0.006020
# 50%                              0.001836            -0.002667
# 75%                              0.011417             0.000604
# max                              0.764597             0.044724
#
#        new_dwellings_ratio  taxpayer_count_growth  unit_price_median  \
# count         11808.000000           16945.000000       1.807500e+04
# mean              0.013600               0.002059       1.011942e+05
# std               0.006844               0.020225       1.803581e+05
# min               0.000631              -0.403889       1.010101e+03
# 25%               0.009042              -0.006339       2.592593e+04
# 50%               0.012692               0.003044       5.217391e+04
# 75%               0.016761               0.011470       1.142857e+05
# max               0.085620               0.242450       4.420875e+06
#
#               count  total_traded_area  in_migrations  out_migrations  \
# count  18075.000000       18075.000000   18075.000000    18075.000000
# mean      92.564869       21779.414385    4438.100360     4457.430396
# std      207.679532       38182.163064   12399.711352    11919.753176
# min        3.000000         320.000000      98.000000       90.000000
# 25%       16.000000        5640.000000     709.500000      840.000000
# 50%       34.000000       10860.000000    1425.000000     1576.000000
# 75%       88.000000       22205.000000    3421.500000     3525.000000
# max     4258.000000      625095.000000  211790.000000   229585.000000
#
#          population  taxpayer_count  taxable_income  \
# count  1.807500e+04    1.694500e+04    1.694500e+04
# mean   1.096984e+05    4.932668e+04    1.663302e+08
# std    2.319912e+05    1.056885e+05    3.991533e+08
# min    2.729000e+03    1.292000e+03    3.578817e+06
# 25%    2.461550e+04    1.053600e+04    2.843368e+07
# 50%    4.705400e+04    2.050100e+04    5.792944e+07
# 75%    1.006185e+05    4.476200e+04    1.353910e+08
# max    3.811873e+06    1.906224e+06    7.965148e+09
#
#        taxable_income_per_taxpayer     total_tax  new_dwellings  \
# count                 16945.000000  1.801100e+04   11808.000000
# mean                   2971.290207  1.688434e+07    1109.924543
# std                     590.292308  4.534869e+07    2503.584914
# min                    1989.133483  5.187260e+05       5.000000
# 25%                    2630.334009  2.987489e+06     183.000000
# 50%                    2861.296683  6.111493e+06     414.000000
# 75%                    3173.355683  1.431097e+07     967.250000
# max                   12667.020000  8.672765e+08   41746.000000
#
#        existing_dwellings  unit_price_median_log_normalized_yearly  \
# count        1.180800e+04                             1.807500e+04
# mean         6.897441e+04                            -9.434592e-18
# std          1.336017e+05                             9.995296e-01
# min          5.814000e+03                            -3.607744e+00
# 25%          1.835450e+04                            -7.236617e-01
# 50%          3.028250e+04                            -5.992616e-02
# 75%          6.270950e+04                             6.956158e-01
# max          1.916062e+06                             3.965719e+00
#
#        count_log_normalized_yearly  total_traded_area_log_normalized_yearly  \
# count                 1.807500e+04                             1.807500e+04
# mean                 -2.232854e-16                             2.358648e-17
# std                   9.995296e-01                             9.995296e-01
# min                  -2.084999e+00                            -3.459538e+00
# 25%                  -7.567006e-01                            -6.735224e-01
# 50%                  -1.270786e-01                            -5.807665e-02
# 75%                   6.619446e-01                             6.177063e-01
# max                   3.931539e+00                             3.798741e+00
#
#        in_migrations_log_normalized_yearly  \
# count                         18075.000000
# mean                              0.390795
# std                               0.731524
# min                              -1.303517
# 25%                              -0.135260
# 50%                               0.287652
# 75%                               0.819501
# max                               3.319728
#
#        out_migrations_log_normalized_yearly  population_log_normalized_yearly  \
# count                          18075.000000                      18075.000000
# mean                               0.392780                          0.432944
# std                                0.731758                          0.701663
# min                               -1.531965                         -1.515944
# 25%                               -0.116337                         -0.061194
# 50%                                0.288224                          0.358155
# 75%                                0.806178                          0.848724
# max                                3.455531                          3.247467
#
#        taxpayer_count_log_normalized_yearly  \
# count                          16945.000000
# mean                               0.549325
# std                                0.711773
# min                               -1.319372
# 25%                                0.044048
# 50%                                0.468081
# 75%                                0.969341
# max                                3.372613
#
#        taxable_income_log_normalized_yearly  \
# count                          16945.000000
# mean                               0.546064
# std                                0.731281
# min                               -1.247956
# 25%                                0.017898
# 50%                                0.453766
# 75%                                0.962132
# max                                3.411731
#
#        taxable_income_per_taxpayer_log_normalized_yearly  \
# count                                       16945.000000
# mean                                            0.273416
# std                                             1.017337
# min                                            -2.098896
# 25%                                            -0.412809
# 50%                                             0.117943
# 75%                                             0.793120
# max                                             9.642084
#
#        total_tax_log_normalized_yearly  new_dwellings_log_normalized_yearly  \
# count                     18011.000000                         11808.000000
# mean                          0.656559                            -0.090774
# std                           0.668104                             1.007393
# min                          -1.076072                            -3.553202
# 25%                           0.162842                            -0.802672
# 50%                           0.765561                            -0.156762
# 75%                           1.049899                             0.524982
# max                           3.485539                             3.413502
#
#        existing_dwellings_log_normalized_yearly  \
# count                              11808.000000
# mean                                  -0.086763
# std                                    1.032552
# min                                   -2.072076
# 25%                                   -0.843800
# 50%                                   -0.305024
# 75%                                    0.474101
# max                                    4.075161
#
#        unit_price_median_pct_chg_normalized_yearly  \
# count                                 1.578300e+04
# mean                                  9.003900e-19
# std                                   9.995247e-01
# min                                  -2.153636e+00
# 25%                                  -4.533846e-01
# 50%                                  -1.411672e-01
# 75%                                   1.859774e-01
# max                                   2.099515e+01
#
#        count_growth_normalized_yearly  yearly_price_growth_normalized_yearly  \
# count                    1.692900e+04                           1.692900e+04
# mean                     5.456350e-18                           1.175214e-17
# std                      9.995273e-01                           9.995273e-01
# min                     -2.420212e+00                          -2.299884e+00
# 25%                     -5.592166e-01                          -4.162023e-01
# 50%                     -1.499312e-01                          -1.313127e-01
# 75%                      3.421786e-01                           1.578113e-01
# max                      1.165666e+01                           3.239772e+01
#
#        total_tax_growth_normalized_yearly  \
# count                        17991.000000
# mean                             0.043077
# std                              0.976708
# min                            -15.073015
# 25%                             -0.290109
# 50%                             -0.010292
# 75%                              0.301357
# max                             31.179627
#
#        taxable_income_growth_normalized_yearly  \
# count                             16945.000000
# mean                                  0.036446
# std                                   0.691877
# min                                  -9.088769
# 25%                                  -0.236532
# 50%                                   0.021498
# 75%                                   0.279377
# max                                  17.612125
#
#        taxable_income_per_taxpayer_growth_normalized_yearly  \
# count                                       16945.000000
# mean                                           -0.024807
# std                                             0.706902
# min                                           -10.693872
# 25%                                            -0.252952
# 50%                                            -0.038019
# 75%                                             0.175740
# max                                            19.002890
#
#        net_migration_ratio_normalized_yearly  \
# count                           18075.000000
# mean                                0.148397
# std                                 0.668856
# min                                -7.356845
# 25%                                -0.250117
# 50%                                 0.118761
# 75%                                 0.487821
# max                                 5.782456
#
#        new_dwellings_ratio_normalized_yearly  \
# count                           11808.000000
# mean                               -0.077213
# std                                 0.935400
# min                                -2.167483
# 25%                                -0.711322
# 50%                                -0.164010
# 75%                                 0.392031
# max                                 9.451687
#
#        taxpayer_count_growth_normalized_yearly  migrations_is_available  \
# count                             16945.000000                  18075.0
# mean                                  0.114413                      1.0
# std                                   0.679608                      0.0
# min                                 -14.401495                      1.0
# 25%                                  -0.238361                      1.0
# 50%                                   0.102843                      1.0
# 75%                                   0.452754                      1.0
# max                                   9.828815                      1.0
#
#        taxable_income_is_available  dwellings_is_available  \
# count                 18075.000000            18075.000000
# mean                      0.937483                0.653278
# std                       0.242099                0.475939
# min                       0.000000                0.000000
# 25%                       1.000000                0.000000
# 50%                       1.000000                1.000000
# 75%                       1.000000                1.000000
# max                       1.000000                1.000000
#
#        total_tax_is_available  metric_pct_chg_is_available
# count            18075.000000                 18075.000000
# mean                 0.996459                     0.873195
# std                  0.059401                     0.332764
# min                  0.000000                     0.000000
# 25%                  1.000000                     1.000000
# 50%                  1.000000                     1.000000
# 75%                  1.000000                     1.000000
# max                  1.000000                     1.000000
