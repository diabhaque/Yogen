# %%
import warnings

import numpy as np
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt

from jre_utils.datapath import (
    factor_data_paths,
    model_ready_data_paths,
    get_derived_csv_path,
    get_derived_lpa_path,
    get_derived_plps_path,
)

from jre_utils.process import (
    get_most_active_municipalities
)

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %%
asset_type = "building"

metrics = {
    "weighted_mean": "unit_price_wmean",
    "weighted_median": "unit_price_wmedian",
    "mean": "unit_price_mean",
    "median": "unit_price_median",
}

dataset_paths = {
    "transactions": get_derived_csv_path(asset_type),
    "lpa": get_derived_lpa_path(),
    "plps": get_derived_plps_path()
}

granularity_columns = ["area", "area_code"]
group_by_columns = granularity_columns + ["year"]
display_columns = ["unit_price", "total_traded_area", "count"]

metric_key = "median"
metric = metrics[metric_key]
metric_pct_chg = metric + "_pct_chg"
upcoming_metric = "upcoming_" + metric
upcoming_metric_pct_chg = "upcoming_" + metric_pct_chg

# %%
population_path = factor_data_paths["processed"]["population"]["municipality"]
migration_path = factor_data_paths["processed"]["migration"]["municipality"]
taxable_income_path = factor_data_paths["processed"]["taxable_income"]["municipality"]
new_dwellings_path = factor_data_paths["processed"]["new_dwellings"]["municipality"]
lfs_revenue_path = factor_data_paths["processed"]["lfs_revenue_breakdown"]["municipality"]

population_df = pd.read_csv(population_path)
migration_df = pd.read_csv(migration_path)
taxable_income_df = pd.read_csv(taxable_income_path)
new_dwellings_df = pd.read_csv(new_dwellings_path)
lfs_revenue_df= pd.read_csv(lfs_revenue_path)

# %%
datasets = {name: pd.read_csv(path) for name, path in dataset_paths.items()}
for name, df in datasets.items():
    datasets[name] = (
        datasets[name]
        .merge(population_df, on=group_by_columns, how="left")
        .merge(migration_df, on=group_by_columns, how="left")
        .merge(taxable_income_df, on=group_by_columns, how="left")
        .merge(new_dwellings_df, on=group_by_columns, how="left")
        .merge(lfs_revenue_df, on=group_by_columns, how="left")
    )

    datasets[name]["migrations_is_available"] = (
        datasets[name]["net_migration_ratio"].notnull().astype(int)
    )
    datasets[name]["taxable_income_is_available"] = (
        datasets[name]["taxable_income"].notnull().astype(int)
    )
    datasets[name]["total_tax_is_available"] = (
        datasets[name]["total_tax"].notnull().astype(int)
    )

    # Might go back and undo the new dwellings filling for unknown municipalities.
    datasets[name]["dwellings_is_available"] = (
        datasets[name]["new_dwellings"].notnull().astype(int)
    )

    datasets[name] = datasets[name].fillna(0)
    datasets[name] = datasets["df"].sort_values(by=group_by_columns, ascending=True)
    datasets[name][metric_pct_chg] = (
        datasets["df"].groupby(granularity_columns)[metric].pct_change()
    )
    datasets[name][upcoming_metric_pct_chg] = datasets[name].groupby(granularity_columns)[metric_pct_chg].shift(-1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/diab/Desktop/japan_re/notebooks/dataset_building/xgb_pretrain.ipynb Cell 4 line 4
#       <a href='vscode-notebook-cell:/Users/diab/Desktop/japan_re/notebooks/dataset_building/xgb_pretrain.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> datasets = {name: pd.read_csv(path) for name, path in dataset_paths.items()}
#       <a href='vscode-notebook-cell:/Users/diab/Desktop/japan_re/notebooks/dataset_building/xgb_pretrain.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> for name, df in datasets.items():
#       <a href='vscode-notebook-cell:/Users/diab/Desktop/japan_re/notebooks/dataset_building/xgb_pretrain.ipynb#X22sZmlsZQ%3D%3D?line=2'>3</a>     datasets["name"] = (
# ----> <a href='vscode-notebook-cell:/Users/diab/Desktop/japan_re/notebooks/dataset_building/xgb_pretrain.ipynb#X22sZmlsZQ%3D%3D?line=3'>4</a>         datasets["name"]
#       <a href='vscode-notebook-cell:/Users/diab/Desktop/japan_re/notebooks/dataset_building/xgb_pretrain.ipynb#X22sZmlsZQ%3D%3D?line=4'>5</a>         .merge(population_df, on=group_by_columns, how="left")
#       <a href='vscode-notebook-cell:/Users/diab/Desktop/japan_re/notebooks/dataset_building/xgb_pretrain.ipynb#X22sZmlsZQ%3D%3D?line=5'>6</a>         .merge(migration_df, on=group_by_columns, how="left")
#       <a href='vscode-notebook-cell:/Users/diab/Desktop/japan_re/notebooks/dataset_building/xgb_pretrain.ipynb#X22sZmlsZQ%3D%3D?line=6'>7</a>         .merge(taxable_income_df, on=group_by_columns, how="left")
#       <a href='vscode-notebook-cell:/Users/diab/Desktop/japan_re/notebooks/dataset_building/xgb_pretrain.ipynb#X22sZmlsZQ%3D%3D?line=7'>8</a>         .merge(new_dwellings_df, on=group_by_columns, how="left")
#       <a href='vscode-notebook-cell:/Users/diab/Desktop/japan_re/notebooks/dataset_building/xgb_pretrain.ipynb#X22sZmlsZQ%3D%3D?line=8'>9</a>         .merge(lfs_revenue_df, on=group_by_columns, how="left")
#      <a href='vscode-notebook-cell:/Users/diab/Desktop/japan_re/notebooks/dataset_building/xgb_pretrain.ipynb#X22sZmlsZQ%3D%3D?line=9'>10</a>     )
#      <a href='vscode-notebook-cell:/Users/diab/Desktop/japan_re/notebooks/dataset_building/xgb_pretrain.ipynb#X22sZmlsZQ%3D%3D?line=11'>12</a>     datasets["name"]["migrations_is_available"] = (
#      <a href='vscode-notebook-cell:/Users/diab/Desktop/japan_re/notebooks/dataset_building/xgb_pretrain.ipynb#X22sZmlsZQ%3D%3D?line=12'>13</a>         datasets["name"]["net_migration_ratio"].notnull().astype(int)
#      <a href='vscode-notebook-cell:/Users/diab/Desktop/japan_re/notebooks/dataset_building/xgb_pretrain.ipynb#X22sZmlsZQ%3D%3D?line=13'>14</a>     )
#      <a href='vscode-notebook-cell:/Users/diab/Desktop/japan_re/notebooks/dataset_building/xgb_pretrain.ipynb#X22sZmlsZQ%3D%3D?line=14'>15</a>     datasets["name"]["taxable_income_is_available"] = (
#      <a href='vscode-notebook-cell:/Users/diab/Desktop/japan_re/notebooks/dataset_building/xgb_pretrain.ipynb#X22sZmlsZQ%3D%3D?line=15'>16</a>         datasets["name"]["taxable_income"].notnull().astype(int)
#      <a href='vscode-notebook-cell:/Users/diab/Desktop/japan_re/notebooks/dataset_building/xgb_pretrain.ipynb#X22sZmlsZQ%3D%3D?line=16'>17</a>     )
#
# KeyError: 'name'

# %%
# prepare metrics
df = df.sort_values(by=group_by_columns, ascending=True)
df[metric_pct_chg] = df.groupby(granularity_columns)[metric].pct_change()

# set up target variables
df[upcoming_metric_pct_chg] = df.groupby(granularity_columns)[metric_pct_chg].shift(-1)

# time box
# start_year = 2005
# end_year = 2023

# df = df[(df["year"] >= start_year) & (df["year"] <= end_year)]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27728 entries, 18191 to 15439
# Data columns (total 27 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   year                                27728 non-null  int64
#  1   area_code                           27728 non-null  int64
#  2   area                                27728 non-null  object
#  3   unit_price_wmean                    27728 non-null  float64
#  4   unit_price_wmedian                  27728 non-null  float64
#  5   unit_price_mean                     27728 non-null  float64
#  6   unit_price_median                   27728 non-null  float64
#  7   total_traded_area                   27728 non-null  float64
#  8   count                               27728 non-null  float64
#  9   population                          27728 non-null  float64
#  10  net_migration_ratio                 27728 non-null  float64
#  11  taxable_income                      27728 non-null  float64
#  12  taxpayer_count                      27728 non-null  float64
#  13  taxable_income_per_taxpayer         27728 non-null  float64
#  14  taxable_income_growth               27728 non-null  float64
#  15  taxable_income_per_taxpayer_growth  27728 non-null  float64
#  16  new_dwellings                       27728 non-null  float64
#  17  existing_dwellings                  27728 non-null  float64
#  18  new_dwellings_ratio                 27728 non-null  float64
#  19  total_tax                           27728 non-null  float64
#  20  total_tax_growth                    27728 non-null  float64
#  21  migrations_is_available             27728 non-null  int64
#  22  taxable_income_is_available         27728 non-null  int64
#  23  total_tax_is_available              27728 non-null  int64
#  24  dwellings_is_available              27728 non-null  int64
#  25  unit_price_median_pct_chg           25992 non-null  float64
#  26  upcoming_unit_price_median_pct_chg  25992 non-null  float64
# dtypes: float64(20), int64(6), object(1)
# memory usage: 5.9+ MB

# %%
# most frequent municipalities
# skip this and build custom cost function using count as parameter. The lower the count, the lower the cost.

# df = get_most_active_municipalities(df, n=1500)
# df = df[df["count"] > 5]

# %%
y_columns = [upcoming_metric_pct_chg]

X_categorical_columns = ["area_code", "area"]

X_basic_columns = [
    "year",
    "population",
    "count",
    "total_traded_area",
    "taxable_income_per_taxpayer",
    "taxable_income_per_taxpayer_growth",
    "total_tax",
    "migrations_is_available",
    "taxable_income_is_available",
    "total_tax_is_available",
    "dwellings_is_available",
]

X_engineering_columns = [
    "net_migration_ratio",
    "taxable_income_growth",
    "new_dwellings_ratio",
    "total_tax_growth",
    metric_pct_chg,
]

initial_columns = (
    X_categorical_columns + X_basic_columns + X_engineering_columns + y_columns
)

df = df[initial_columns]
df[X_categorical_columns] = df[X_categorical_columns].astype("category")
df = df.dropna()

# %%
lag = 1

X_engineered_columns = []

for col in X_engineering_columns:
    df["multiplier"] = df[col] + 1
    df[f"{col}_ma3"] = df.groupby(granularity_columns)[col].transform(
        lambda x: x.rolling(3, 1).mean()
    )
    df[f"{col}_cumu3"] = df.groupby(granularity_columns)["multiplier"].transform(
        lambda x: x.rolling(3, 1).apply(np.prod, raw=True)
    )

    X_engineered_columns.append(f"{col}_ma3")
    X_engineered_columns.append(f"{col}_cumu3")
    print(f"{col}_ma3")
    print(f"{col}_cumu3")

    for i in range(1, lag + 1):
        df[f"{col}_lag{i}"] = df.groupby(granularity_columns)[col].shift(i)
        X_engineered_columns.append(f"{col}_lag{i}")
        print(f"{col}_lag{i}")

df[X_engineered_columns] = df[X_engineered_columns].fillna(0)
# Out:
# net_migration_ratio_ma3
# net_migration_ratio_cumu3
# net_migration_ratio_lag1
# taxable_income_growth_ma3
# taxable_income_growth_cumu3
# taxable_income_growth_lag1
# new_dwellings_ratio_ma3
# new_dwellings_ratio_cumu3
# new_dwellings_ratio_lag1
# total_tax_growth_ma3
# total_tax_growth_cumu3
# total_tax_growth_lag1
# unit_price_median_pct_chg_ma3
# unit_price_median_pct_chg_cumu3
# unit_price_median_pct_chg_lag1

# %%
X_engineered_columns
# Out:
# ['net_migration_ratio_ma3',
#  'net_migration_ratio_cumu3',
#  'net_migration_ratio_lag1',
#  'taxable_income_growth_ma3',
#  'taxable_income_growth_cumu3',
#  'taxable_income_growth_lag1',
#  'new_dwellings_ratio_ma3',
#  'new_dwellings_ratio_cumu3',
#  'new_dwellings_ratio_lag1',
#  'total_tax_growth_ma3',
#  'total_tax_growth_cumu3',
#  'total_tax_growth_lag1',
#  'unit_price_median_pct_chg_ma3',
#  'unit_price_median_pct_chg_cumu3',
#  'unit_price_median_pct_chg_lag1']

# %%
df
# Out:
#       area_code                         area  year  population  count  \
# 18140     23441           Aichi-ken Agui-cho  2008         0.0   14.0
# 18086     23441           Aichi-ken Agui-cho  2009         0.0   31.0
# 18034     23441           Aichi-ken Agui-cho  2010     25695.0   41.0
# 17982     23441           Aichi-ken Agui-cho  2011     26248.0   40.0
# 17929     23441           Aichi-ken Agui-cho  2012     26793.0   45.0
# ...         ...                          ...   ...         ...    ...
# 15560     19205  Yamanashi-ken Yamanashi-shi  2018     33789.0   14.0
# 15535     19205  Yamanashi-ken Yamanashi-shi  2019     33574.0   22.0
# 15510     19205  Yamanashi-ken Yamanashi-shi  2020     33435.0   16.0
# 15485     19205  Yamanashi-ken Yamanashi-shi  2021     33357.0   30.0
# 15461     19205  Yamanashi-ken Yamanashi-shi  2022     33364.0   25.0
#
#        total_traded_area  taxable_income_per_taxpayer  \
# 18140             2905.0                  3549.241030
# 18086             6100.0                  3483.893426
# 18034             8265.0                  3213.665886
# 17982            11000.0                  3245.342254
# 17929             9585.0                  3270.662717
# ...                  ...                          ...
# 15560             7400.0                  2832.607559
# 15535             8785.0                  2861.296683
# 15510             9255.0                  2870.243213
# 15485            13315.0                  2956.122862
# 15461            10645.0                     0.000000
#
#        taxable_income_per_taxpayer_growth  total_tax  migrations_is_available  \
# 18140                            0.003820  3957657.0                        0
# 18086                           -0.018412  3776007.0                        0
# 18034                           -0.077565  3646545.0                        1
# 17982                            0.009857  3801941.0                        1
# 17929                            0.007802  3842470.0                        1
# ...                                   ...        ...                      ...
# 15560                            0.021537  3995097.0                        1
# 15535                            0.010128  4083057.0                        1
# 15510                            0.003127  4119255.0                        1
# 15485                            0.029921  4065382.0                        1
# 15461                            0.000000  4197453.0                        1
#
#        taxable_income_is_available  total_tax_is_available  \
# 18140                            1                       1
# 18086                            1                       1
# 18034                            1                       1
# 17982                            1                       1
# 17929                            1                       1
# ...                            ...                     ...
# 15560                            1                       1
# 15535                            1                       1
# 15510                            1                       1
# 15485                            1                       1
# 15461                            0                       1
#
#        dwellings_is_available  net_migration_ratio  taxable_income_growth  \
# 18140                       0             0.000000               0.003993
# 18086                       0             0.000000              -0.015716
# 18034                       0             0.021522              -0.089172
# 17982                       0             0.020763               0.023952
# 17929                       0             0.012503               0.032618
# ...                       ...                  ...                    ...
# 15560                       1            -0.006363               0.028138
# 15535                       1            -0.004140               0.019458
# 15510                       1            -0.000927               0.004950
# 15485                       1            -0.002338               0.022114
# 15461                       0             0.000210               0.000000
#
#        new_dwellings_ratio  total_tax_growth  unit_price_median_pct_chg  \
# 18140             0.000000          0.016734                   0.798786
# 18086             0.000000         -0.045898                   0.237847
# 18034             0.000000         -0.034285                   0.062112
# 17982             0.000000          0.042615                   0.000000
# 17929             0.000000          0.010660                   0.026316
# ...                    ...               ...                        ...
# 15560             0.007798          0.008340                  -0.439361
# 15535             0.008447          0.022017                   0.407036
# 15510             0.008121          0.008865                  -0.628406
# 15485             0.011216         -0.013078                   0.628207
# 15461             0.000000          0.032487                   0.083744
#
#        upcoming_unit_price_median_pct_chg  multiplier  \
# 18140                            0.237847    1.798786
# 18086                            0.062112    1.237847
# 18034                            0.000000    1.062112
# 17982                            0.026316    1.000000
# 17929                           -0.037695    1.026316
# ...                                   ...         ...
# 15560                            0.407036    0.560639
# 15535                           -0.628406    1.407036
# 15510                            0.628207    0.371594
# 15485                            0.083744    1.628207
# 15461                            0.047021    1.083744
#
#        net_migration_ratio_ma3  net_migration_ratio_cumu3  \
# 18140                 0.000000                   1.000000
# 18086                 0.000000                   1.000000
# 18034                 0.007174                   1.021522
# 17982                 0.014095                   1.042732
# 17929                 0.018263                   1.055770
# ...                        ...                        ...
# 15560                -0.004876                   0.985442
# 15535                -0.005150                   0.984628
# 15510                -0.003810                   0.988606
# 15485                -0.002469                   0.992610
# 15461                -0.001019                   0.996946
#
#        net_migration_ratio_lag1  taxable_income_growth_ma3  \
# 18140                  0.000000                   0.003993
# 18086                  0.000000                  -0.005861
# 18034                  0.000000                  -0.033632
# 17982                  0.021522                  -0.026979
# 17929                  0.020763                  -0.010867
# ...                         ...                        ...
# 15560                 -0.004947                   0.011771
# 15535                 -0.006363                   0.015664
# 15510                 -0.004140                   0.017515
# 15485                 -0.000927                   0.015507
# 15461                 -0.002338                   0.009021
#
#        taxable_income_growth_cumu3  taxable_income_growth_lag1  \
# 18140                     1.003993                    0.000000
# 18086                     0.988214                    0.003993
# 18034                     0.900093                   -0.015716
# 17982                     0.917987                   -0.089172
# 17929                     0.963065                    0.023952
# ...                            ...                         ...
# 15560                     1.035509                   -0.000603
# 15535                     1.047511                    0.028138
# 15510                     1.053331                    0.019458
# 15485                     1.047160                    0.004950
# 15461                     1.027173                    0.022114
#
#        new_dwellings_ratio_ma3  new_dwellings_ratio_cumu3  \
# 18140                 0.000000                   1.000000
# 18086                 0.000000                   1.000000
# 18034                 0.000000                   1.000000
# 17982                 0.000000                   1.000000
# 17929                 0.000000                   1.000000
# ...                        ...                        ...
# 15560                 0.009116                   1.027596
# 15535                 0.008524                   1.025789
# 15510                 0.008122                   1.024564
# 15485                 0.009261                   1.028039
# 15461                 0.006446                   1.019428
#
#        new_dwellings_ratio_lag1  total_tax_growth_ma3  total_tax_growth_cumu3  \
# 18140                  0.000000              0.016734                1.016734
# 18086                  0.000000             -0.014582                0.970067
# 18034                  0.000000             -0.021150                0.936808
# 17982                  0.000000             -0.012523                0.960654
# 17929                  0.000000              0.006330                1.017601
# ...                         ...                   ...                     ...
# 15560                  0.009326              0.006241                1.018796
# 15535                  0.007798              0.009709                1.029275
# 15510                  0.008447              0.013074                1.039677
# 15485                  0.008121              0.005935                1.017593
# 15461                  0.011216              0.009425                1.028017
#
#        total_tax_growth_lag1  unit_price_median_pct_chg_ma3  \
# 18140               0.000000                       0.798786
# 18086               0.016734                       0.518317
# 18034              -0.045898                       0.366248
# 17982              -0.034285                       0.099986
# 17929               0.042615                       0.029476
# ...                      ...                            ...
# 15560              -0.001229                       0.147548
# 15535               0.008340                       0.312608
# 15510               0.022017                      -0.220244
# 15485               0.008865                       0.135612
# 15461              -0.013078                       0.027848
#
#        unit_price_median_pct_chg_cumu3  unit_price_median_pct_chg_lag1
# 18140                         1.798786                        0.000000
# 18086                         2.226623                        0.798786
# 18034                         2.364922                        0.237847
# 17982                         1.314732                        0.062112
# 17929                         1.090062                        0.000000
# ...                                ...                             ...
# 15560                         1.007183                        0.970149
# 15535                         1.554131                       -0.439361
# 15510                         0.293128                        0.407036
# 15485                         0.851301                       -0.628406
# 15461                         0.655699                        0.628207
#
# [24261 rows x 35 columns]

# %%
print(f"Initial Size: ", df.shape[0])
q = 0.01
filtered_df = df.copy()
filter_col = y_columns[0]
filtered_df = filtered_df[
    (filtered_df[filter_col] >= filtered_df[filter_col].quantile(q))
    & (filtered_df[filter_col] <= filtered_df[filter_col].quantile(1 - q))
]
print(f"Filtered Size: ", filtered_df.shape[0])
filtered_df.describe()
# Out:
# Initial Size:  24261
# Filtered Size:  23775
#                year    population         count  total_traded_area  \
# count  23775.000000  2.377500e+04  23775.000000       23775.000000
# mean    2014.930431  8.141953e+04     74.392681       19751.101157
# std        4.313935  2.027308e+05    195.034030       39135.489253
# min     2006.000000  0.000000e+00      1.000000          60.000000
# 25%     2011.000000  1.067150e+04      7.000000        3280.000000
# 50%     2015.000000  2.907900e+04     22.000000        8690.000000
# 75%     2019.000000  7.182200e+04     66.000000       20470.000000
# max     2022.000000  3.811873e+06   4358.000000      666150.000000
#
#        taxable_income_per_taxpayer  taxable_income_per_taxpayer_growth  \
# count                 23775.000000                        23775.000000
# mean                   2690.665748                            0.001995
# std                     882.162071                            0.032451
# min                       0.000000                           -0.694693
# 25%                    2498.573185                           -0.008284
# 50%                    2739.682182                            0.000984
# 75%                    3044.601308                            0.012170
# max                   12667.020000                            0.915431
#
#           total_tax  migrations_is_available  taxable_income_is_available  \
# count  2.377500e+04             23775.000000                 23775.000000
# mean   1.269398e+07                 0.987213                     0.937119
# std    3.993031e+07                 0.112355                     0.242754
# min    0.000000e+00                 0.000000                     0.000000
# 25%    1.333330e+06                 1.000000                     1.000000
# 50%    3.688276e+06                 1.000000                     1.000000
# 75%    1.018640e+07                 1.000000                     1.000000
# max    8.672765e+08                 1.000000                     1.000000
#
#        total_tax_is_available  dwellings_is_available  net_migration_ratio  \
# count            23775.000000             23775.00000         23775.000000
# mean                 0.997476                 0.48387            -0.003735
# std                  0.050174                 0.49975             0.007824
# min                  0.000000                 0.00000            -0.313065
# 25%                  1.000000                 0.00000            -0.007382
# 50%                  1.000000                 0.00000            -0.003544
# 75%                  1.000000                 1.00000             0.000000
# max                  1.000000                 1.00000             0.144218
#
#        taxable_income_growth  new_dwellings_ratio  total_tax_growth  \
# count           23775.000000         23775.000000      23775.000000
# mean                0.002121             0.006455          0.003724
# std                 0.043424             0.008183          0.064709
# min                -0.682739             0.000000         -0.677251
# 25%                -0.011612             0.000000         -0.016724
# 50%                 0.002800             0.000000          0.001463
# 75%                 0.019456             0.012246          0.018862
# max                 0.882113             0.120270          4.759148
#
#        unit_price_median_pct_chg  upcoming_unit_price_median_pct_chg  \
# count               23775.000000                        23775.000000
# mean                    0.230019                            0.149561
# std                     1.747214                            0.792869
# min                    -0.989961                           -0.878230
# 25%                    -0.220629                           -0.221964
# 50%                    -0.007300                           -0.006847
# 75%                     0.228974                            0.232972
# max                    85.124402                            6.439015
#
#          multiplier  net_migration_ratio_ma3  net_migration_ratio_cumu3  \
# count  23775.000000             23775.000000               23775.000000
# mean       1.230019                -0.003881                   0.989676
# std        1.747214                 0.006816                   0.018581
# min        0.010039                -0.224323                   0.461571
# 25%        0.779371                -0.007379                   0.980046
# 50%        0.992700                -0.003861                   0.989802
# 75%        1.228974                -0.000271                   0.999237
# max       86.124402                 0.050664                   1.153130
#
#        net_migration_ratio_lag1  taxable_income_growth_ma3  \
# count              23775.000000               23775.000000
# mean                  -0.003488                   0.000949
# std                    0.007308                   0.028087
# min                   -0.203379                  -0.682739
# 25%                   -0.007106                  -0.014373
# 50%                   -0.003050                   0.003711
# 75%                    0.000000                   0.015727
# max                    0.144218                   0.367086
#
#        taxable_income_growth_cumu3  taxable_income_growth_lag1  \
# count                 23775.000000                23775.000000
# mean                      1.004536                    0.001896
# std                       0.075366                    0.043381
# min                       0.199410                   -0.682739
# 25%                       0.964108                   -0.011389
# 50%                       1.009193                    0.002148
# 75%                       1.045047                    0.018940
# max                       2.188546                    0.882113
#
#        new_dwellings_ratio_ma3  new_dwellings_ratio_cumu3  \
# count             23775.000000               23775.000000
# mean                  0.006875                   1.019255
# std                   0.008166                   0.023219
# min                   0.000000                   1.000000
# 25%                   0.000000                   1.000000
# 50%                   0.003959                   1.010201
# 75%                   0.012701                   1.035692
# max                   0.092722                   1.303819
#
#        new_dwellings_ratio_lag1  total_tax_growth_ma3  total_tax_growth_cumu3  \
# count              23775.000000          23775.000000            23775.000000
# mean                   0.006453              0.002641                1.006732
# std                    0.008184              0.038691                0.101676
# min                    0.000000             -0.417418                0.297333
# 25%                    0.000000             -0.011478                0.968346
# 50%                    0.000000              0.000943                1.001804
# 75%                    0.012246              0.012300                1.033584
# max                    0.120270              1.586710                5.757765
#
#        total_tax_growth_lag1  unit_price_median_pct_chg_ma3  \
# count           23775.000000                   23775.000000
# mean                0.001607                       0.242274
# std                 0.060852                       1.103677
# min                -0.677251                      -0.958065
# 25%                -0.015917                      -0.049768
# 50%                 0.000000                       0.033039
# 75%                 0.014985                       0.202814
# max                 4.759148                      35.441026
#
#        unit_price_median_pct_chg_cumu3  unit_price_median_pct_chg_lag1
# count                     23775.000000                    23775.000000
# mean                          1.195414                        0.237063
# std                           1.569760                        1.898766
# min                           0.003056                       -0.991268
# 25%                           0.729085                       -0.197157
# 50%                           0.967029                        0.000000
# 75%                           1.216410                        0.194873
# max                          82.490909                       85.124402

# %%
filtered_df.to_csv(model_ready_data_paths[f"xgb_{dataset_key}_{metric_key}"], index=False)

# %%
area_code = 13102
test_df = filtered_df[filtered_df["area_code"] == area_code]
test_df[["year", metric_pct_chg, upcoming_metric_pct_chg]]
# Out:
#        year  unit_price_median_pct_chg  upcoming_unit_price_median_pct_chg
# 1937   1998                  -0.099057                           -0.041885
# 3340   1999                  -0.041885                           -0.180328
# 4744   2000                  -0.180328                           -0.080000
# 6152   2001                  -0.080000                           -0.094203
# 7562   2002                  -0.094203                           -0.040000
# 8978   2003                  -0.040000                           -0.025000
# 10401  2004                  -0.025000                            0.042735
# 11868  2005                   0.042735                            0.110656
# 15182  2007                   0.239852                            0.101190
# 16883  2008                   0.101190                           -0.140541
# 18586  2009                  -0.140541                           -0.100629
# 20290  2010                  -0.100629                           -0.034965
# 21988  2011                  -0.034965                           -0.014493
# 23691  2012                  -0.014493                            0.014706
# 25398  2013                   0.014706                            0.094203
# 27107  2014                   0.094203                            0.066225
# 28817  2015                   0.066225                            0.086957
# 30528  2016                   0.086957                            0.057143
# 32241  2017                   0.057143                            0.081081
# 33957  2018                   0.081081                            0.105000
# 35673  2019                   0.105000                            0.018100
# 37393  2020                   0.018100                           -0.013333
# 39113  2021                  -0.013333                            0.009009
# 40833  2022                   0.009009                            0.040179

# %%
test_year = 2021
presentation_df = filtered_df[filtered_df["area_code"].astype(int) // 1000 == 13]
presentation_df = presentation_df[presentation_df["year"] == test_year]
presentation_df = presentation_df.sort_index(axis=1)
presentation_df["upcoming_return"] = presentation_df[upcoming_metric_pct_chg]
presentation_df = presentation_df.sort_values(by=upcoming_metric_pct_chg, ascending=False).reset_index(drop=True)

drop_columns = [upcoming_metric_pct_chg, "area_code"]
presentation_df.drop(columns=drop_columns).style.background_gradient(cmap="cividis")
# Out:
# <style type="text/css">
# #T_ef386_row0_col1, #T_ef386_row7_col5, #T_ef386_row16_col9, #T_ef386_row21_col7, #T_ef386_row23_col12, #T_ef386_row25_col6, #T_ef386_row25_col8, #T_ef386_row27_col7, #T_ef386_row28_col12, #T_ef386_row29_col7, #T_ef386_row31_col10, #T_ef386_row34_col25, #T_ef386_row42_col29, #T_ef386_row43_col19, #T_ef386_row43_col29, #T_ef386_row44_col29, #T_ef386_row45_col29, #T_ef386_row46_col29, #T_ef386_row47_col29, #T_ef386_row48_col29, #T_ef386_row49_col29, #T_ef386_row50_col29 {
#   background-color: #757575;
#   color: #f1f1f1;
# }
# #T_ef386_row0_col2, #T_ef386_row0_col24, #T_ef386_row6_col2, #T_ef386_row6_col24, #T_ef386_row17_col7, #T_ef386_row25_col27 {
#   background-color: #424e6c;
#   color: #f1f1f1;
# }
# #T_ef386_row0_col3, #T_ef386_row9_col15, #T_ef386_row11_col17, #T_ef386_row25_col16, #T_ef386_row35_col21, #T_ef386_row39_col22, #T_ef386_row54_col10 {
#   background-color: #555b6d;
#   color: #f1f1f1;
# }
# #T_ef386_row0_col4, #T_ef386_row8_col18, #T_ef386_row12_col3, #T_ef386_row17_col20, #T_ef386_row18_col14, #T_ef386_row25_col13 {
#   background-color: #6f7073;
#   color: #f1f1f1;
# }
# #T_ef386_row0_col5, #T_ef386_row1_col5, #T_ef386_row4_col4, #T_ef386_row4_col5, #T_ef386_row7_col25, #T_ef386_row13_col22, #T_ef386_row17_col3, #T_ef386_row44_col20 {
#   background-color: #6b6d72;
#   color: #f1f1f1;
# }
# #T_ef386_row0_col6, #T_ef386_row0_col12, #T_ef386_row1_col17, #T_ef386_row1_col19, #T_ef386_row2_col7, #T_ef386_row23_col3, #T_ef386_row25_col5, #T_ef386_row35_col8, #T_ef386_row37_col10, #T_ef386_row48_col14 {
#   background-color: #707173;
#   color: #f1f1f1;
# }
# #T_ef386_row0_col7, #T_ef386_row2_col8, #T_ef386_row4_col7, #T_ef386_row7_col3, #T_ef386_row31_col8, #T_ef386_row50_col5, #T_ef386_row54_col4 {
#   background-color: #727374;
#   color: #f1f1f1;
# }
# #T_ef386_row0_col8, #T_ef386_row37_col9, #T_ef386_row39_col4, #T_ef386_row56_col20 {
#   background-color: #878478;
#   color: #f1f1f1;
# }
# #T_ef386_row0_col9, #T_ef386_row0_col10, #T_ef386_row12_col4, #T_ef386_row18_col4, #T_ef386_row22_col21, #T_ef386_row24_col6, #T_ef386_row33_col9, #T_ef386_row33_col25, #T_ef386_row48_col3, #T_ef386_row53_col6, #T_ef386_row54_col21 {
#   background-color: #898578;
#   color: #f1f1f1;
# }
# #T_ef386_row0_col11, #T_ef386_row3_col29, #T_ef386_row6_col14, #T_ef386_row9_col14, #T_ef386_row41_col3 {
#   background-color: #c6b667;
#   color: #000000;
# }
# #T_ef386_row0_col13, #T_ef386_row4_col10, #T_ef386_row4_col19, #T_ef386_row21_col4, #T_ef386_row24_col15, #T_ef386_row30_col5, #T_ef386_row54_col3 {
#   background-color: #7f7e78;
#   color: #f1f1f1;
# }
# #T_ef386_row0_col14, #T_ef386_row3_col12, #T_ef386_row11_col6, #T_ef386_row15_col9, #T_ef386_row15_col10, #T_ef386_row17_col13, #T_ef386_row28_col6, #T_ef386_row32_col19, #T_ef386_row37_col20, #T_ef386_row40_col14 {
#   background-color: #7d7c78;
#   color: #f1f1f1;
# }
# #T_ef386_row0_col15, #T_ef386_row9_col4, #T_ef386_row20_col21, #T_ef386_row27_col20, #T_ef386_row39_col19, #T_ef386_row44_col21, #T_ef386_row56_col4 {
#   background-color: #828079;
#   color: #f1f1f1;
# }
# #T_ef386_row0_col16, #T_ef386_row5_col16, #T_ef386_row5_col18, #T_ef386_row11_col22, #T_ef386_row18_col1, #T_ef386_row19_col1, #T_ef386_row35_col1, #T_ef386_row40_col2, #T_ef386_row40_col24, #T_ef386_row54_col20, #T_ef386_row55_col26 {
#   background-color: #2f426d;
#   color: #f1f1f1;
# }
# #T_ef386_row0_col17, #T_ef386_row3_col10, #T_ef386_row27_col26, #T_ef386_row38_col14 {
#   background-color: #9e9676;
#   color: #f1f1f1;
# }
# #T_ef386_row0_col18, #T_ef386_row3_col22, #T_ef386_row29_col6, #T_ef386_row31_col5, #T_ef386_row33_col15, #T_ef386_row33_col21, #T_ef386_row53_col14, #T_ef386_row56_col10, #T_ef386_row57_col20 {
#   background-color: #969077;
#   color: #f1f1f1;
# }
# #T_ef386_row0_col19, #T_ef386_row13_col5, #T_ef386_row14_col4, #T_ef386_row14_col20, #T_ef386_row22_col17, #T_ef386_row27_col22, #T_ef386_row35_col6, #T_ef386_row36_col3, #T_ef386_row36_col17, #T_ef386_row46_col8 {
#   background-color: #8c8878;
#   color: #f1f1f1;
# }
# #T_ef386_row0_col20, #T_ef386_row4_col8, #T_ef386_row17_col4, #T_ef386_row24_col13, #T_ef386_row28_col9, #T_ef386_row47_col14, #T_ef386_row56_col3 {
#   background-color: #7e7c78;
#   color: #f1f1f1;
# }
# #T_ef386_row0_col21, #T_ef386_row13_col29, #T_ef386_row14_col29, #T_ef386_row19_col19, #T_ef386_row23_col14 {
#   background-color: #afa471;
#   color: #f1f1f1;
# }
# #T_ef386_row0_col22, #T_ef386_row2_col18, #T_ef386_row4_col9, #T_ef386_row6_col6, #T_ef386_row11_col3, #T_ef386_row13_col17, #T_ef386_row16_col17, #T_ef386_row19_col3, #T_ef386_row23_col1, #T_ef386_row28_col8, #T_ef386_row37_col29, #T_ef386_row39_col17, #T_ef386_row56_col1 {
#   background-color: #817f78;
#   color: #f1f1f1;
# }
# #T_ef386_row0_col23, #T_ef386_row2_col2, #T_ef386_row2_col24, #T_ef386_row15_col6, #T_ef386_row19_col11, #T_ef386_row20_col26, #T_ef386_row39_col14, #T_ef386_row48_col4, #T_ef386_row54_col26 {
#   background-color: #4c556c;
#   color: #f1f1f1;
# }
# #T_ef386_row0_col25, #T_ef386_row1_col2, #T_ef386_row1_col24, #T_ef386_row3_col18, #T_ef386_row8_col2, #T_ef386_row8_col24, #T_ef386_row35_col18, #T_ef386_row36_col20, #T_ef386_row47_col15, #T_ef386_row54_col13, #T_ef386_row56_col29 {
#   background-color: #404c6c;
#   color: #f1f1f1;
# }
# #T_ef386_row0_col26, #T_ef386_row11_col21, #T_ef386_row26_col5, #T_ef386_row27_col29, #T_ef386_row29_col4, #T_ef386_row39_col1 {
#   background-color: #958f77;
#   color: #f1f1f1;
# }
# #T_ef386_row0_col27, #T_ef386_row15_col2, #T_ef386_row15_col24, #T_ef386_row25_col2, #T_ef386_row25_col24, #T_ef386_row25_col25, #T_ef386_row32_col15, #T_ef386_row50_col22, #T_ef386_row53_col22, #T_ef386_row54_col15 {
#   background-color: #414d6c;
#   color: #f1f1f1;
# }
# #T_ef386_row0_col28, #T_ef386_row1_col25, #T_ef386_row1_col26, #T_ef386_row1_col27, #T_ef386_row1_col28, #T_ef386_row2_col28, #T_ef386_row3_col28, #T_ef386_row4_col28, #T_ef386_row5_col28, #T_ef386_row6_col28, #T_ef386_row7_col28, #T_ef386_row8_col28, #T_ef386_row9_col28, #T_ef386_row10_col28, #T_ef386_row11_col28, #T_ef386_row12_col2, #T_ef386_row12_col24, #T_ef386_row12_col28, #T_ef386_row13_col28, #T_ef386_row14_col28, #T_ef386_row15_col28, #T_ef386_row16_col14, #T_ef386_row16_col28, #T_ef386_row17_col23, #T_ef386_row17_col28, #T_ef386_row18_col28, #T_ef386_row19_col28, #T_ef386_row20_col28, #T_ef386_row21_col28, #T_ef386_row22_col28, #T_ef386_row23_col28, #T_ef386_row24_col28, #T_ef386_row25_col28, #T_ef386_row26_col28, #T_ef386_row27_col12, #T_ef386_row27_col17, #T_ef386_row27_col28, #T_ef386_row28_col28, #T_ef386_row29_col28, #T_ef386_row30_col28, #T_ef386_row31_col28, #T_ef386_row32_col28, #T_ef386_row33_col28, #T_ef386_row34_col28, #T_ef386_row35_col28, #T_ef386_row36_col28, #T_ef386_row37_col28, #T_ef386_row38_col28, #T_ef386_row39_col28, #T_ef386_row40_col28, #T_ef386_row41_col7, #T_ef386_row41_col8, #T_ef386_row41_col9, #T_ef386_row41_col10, #T_ef386_row41_col11, #T_ef386_row41_col18, #T_ef386_row41_col20, #T_ef386_row41_col22, #T_ef386_row41_col23, #T_ef386_row41_col28, #T_ef386_row42_col7, #T_ef386_row42_col8, #T_ef386_row42_col9, #T_ef386_row42_col10, #T_ef386_row42_col28, #T_ef386_row43_col1, #T_ef386_row43_col7, #T_ef386_row43_col8, #T_ef386_row43_col9, #T_ef386_row43_col10, #T_ef386_row43_col11, #T_ef386_row43_col18, #T_ef386_row43_col23, #T_ef386_row43_col28, #T_ef386_row44_col4, #T_ef386_row44_col5, #T_ef386_row44_col6, #T_ef386_row44_col7, #T_ef386_row44_col8, #T_ef386_row44_col9, #T_ef386_row44_col10, #T_ef386_row44_col11, #T_ef386_row44_col18, #T_ef386_row44_col28, #T_ef386_row45_col1, #T_ef386_row45_col3, #T_ef386_row45_col7, #T_ef386_row45_col8, #T_ef386_row45_col9, #T_ef386_row45_col10, #T_ef386_row45_col11, #T_ef386_row45_col18, #T_ef386_row45_col28, #T_ef386_row46_col28, #T_ef386_row47_col7, #T_ef386_row47_col8, #T_ef386_row47_col9, #T_ef386_row47_col10, #T_ef386_row47_col28, #T_ef386_row48_col1, #T_ef386_row48_col7, #T_ef386_row48_col8, #T_ef386_row48_col9, #T_ef386_row48_col10, #T_ef386_row48_col11, #T_ef386_row48_col13, #T_ef386_row48_col15, #T_ef386_row48_col18, #T_ef386_row48_col20, #T_ef386_row48_col22, #T_ef386_row48_col28, #T_ef386_row

# %%
# sort by median and weighted median to see the difference in ordering.
# Try to find the best metric to use
