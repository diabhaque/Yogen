# %%
import warnings

import numpy as np
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt

from jre_utils.datapath import (
    factor_data_paths,
    model_ready_data_paths,
    get_derived_csv_path,
    get_derived_lpa_path,
    get_derived_plps_path,
)

from jre_utils.process import (
    get_most_active_municipalities
)

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %%
asset_type = "building"

metrics = {
    "weighted_mean": "unit_price_wmean",
    "weighted_median": "unit_price_wmedian",
    "mean": "unit_price_mean",
    "median": "unit_price_median",
}

dataset_paths = {
    "transactions": get_derived_csv_path(asset_type),
    "lpa": get_derived_lpa_path(),
    "plps": get_derived_plps_path()
}

granularity_columns = ["area", "area_code"]
group_by_columns = granularity_columns + ["year"]
display_columns = ["unit_price", "total_traded_area", "count"]

metric = metrics["median"]
metric_pct_chg = metric + "_pct_chg"
upcoming_metric = "upcoming_" + metric
upcoming_metric_pct_chg = "upcoming_" + metric_pct_chg

# %%
dataset_key = "transactions"
core_path = dataset_paths[dataset_key]
population_path = factor_data_paths["processed"]["population"]["municipality"]
migration_path = factor_data_paths["processed"]["migration"]["municipality"]
taxable_income_path = factor_data_paths["processed"]["taxable_income"]["municipality"]
new_dwellings_path = factor_data_paths["processed"]["new_dwellings"]["municipality"]

# %%
df = pd.read_csv(core_path)

population_df = pd.read_csv(population_path)
migration_df = pd.read_csv(migration_path)
taxable_income_df = pd.read_csv(taxable_income_path)
new_dwellings_df = pd.read_csv(new_dwellings_path)

df = (
    df.merge(population_df, on=group_by_columns, how="left")
    .merge(migration_df, on=group_by_columns, how="left")
    .merge(taxable_income_df, on=group_by_columns, how="left")
    .merge(new_dwellings_df, on=group_by_columns, how="left")
)

# %%
# prepare metrics
df = df.sort_values(by=group_by_columns, ascending=True)
df[metric_pct_chg] = df.groupby(granularity_columns)[metric].pct_change()

# set up target variables
df[upcoming_metric_pct_chg] = df.groupby(granularity_columns)[metric_pct_chg].shift(-1)

# time box
# start_year = 2005
# end_year = 2023

# df = df[(df["year"] >= start_year) & (df["year"] <= end_year)]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27728 entries, 18191 to 15439
# Data columns (total 21 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   year                                27728 non-null  int64
#  1   area_code                           27728 non-null  int64
#  2   area                                27728 non-null  object
#  3   unit_price_wmean                    27728 non-null  float64
#  4   unit_price_wmedian                  27728 non-null  float64
#  5   unit_price_mean                     27728 non-null  float64
#  6   unit_price_median                   27728 non-null  float64
#  7   total_traded_area                   27728 non-null  float64
#  8   count                               27728 non-null  float64
#  9   population                          25740 non-null  float64
#  10  net_migration_ratio                 25740 non-null  float64
#  11  taxable_income                      24504 non-null  float64
#  12  taxpayer_count                      24504 non-null  float64
#  13  taxable_income_per_taxpayer         24504 non-null  float64
#  14  taxable_income_growth               24504 non-null  float64
#  15  taxable_income_per_taxpayer_growth  24504 non-null  float64
#  16  new_dwellings                       24260 non-null  float64
#  17  existing_dwellings                  24260 non-null  float64
#  18  new_dwellings_ratio                 24260 non-null  float64
#  19  unit_price_median_pct_chg           25992 non-null  float64
#  20  upcoming_unit_price_median_pct_chg  25992 non-null  float64
# dtypes: float64(18), int64(2), object(1)
# memory usage: 4.7+ MB

# %%
# most frequent municipalities
# skip this and build custom cost function using count as parameter. The lower the count, the lower the cost.

df = get_most_active_municipalities(df, n=1500)
# df = df[df["count"] > 5]

# %%
y_columns = [upcoming_metric_pct_chg]

X_categorical_columns = ["area_code", "area"]

X_basic_columns = [
    "year",
    "population",
    "count",
    "total_traded_area",
    "taxable_income_per_taxpayer",
    "taxable_income_per_taxpayer_growth",
]

X_engineering_columns = [
    "net_migration_ratio",
    "taxable_income_growth",
    "new_dwellings_ratio",
    metric_pct_chg,
]

initial_columns = (
    X_categorical_columns + X_basic_columns + X_engineering_columns + y_columns
)

df = df[initial_columns]
df[X_categorical_columns] = df[X_categorical_columns].astype("category")
df = df.dropna()

# %%
lag = 1

X_engineered_columns = []

for col in X_engineering_columns:
    df["multiplier"] = df[col] + 1
    df[f"{col}_ma3"] = df.groupby(granularity_columns)[col].transform(
        lambda x: x.rolling(3, 1).mean()
    )
    df[f"{col}_cumu3"] = df.groupby(granularity_columns)["multiplier"].transform(
        lambda x: x.rolling(3, 1).apply(np.prod, raw=True)
    )

    X_engineered_columns.append(f"{col}_ma3")
    X_engineered_columns.append(f"{col}_cumu3")
    print(f"{col}_ma3")
    print(f"{col}_cumu3")

    for i in range(1, lag + 1):
        df[f"{col}_lag{i}"] = df.groupby(granularity_columns)[col].shift(i)
        X_engineered_columns.append(f"{col}_lag{i}")
        print(f"{col}_lag{i}")

df[X_engineered_columns] = df[X_engineered_columns].fillna(0)
# Out:
# net_migration_ratio_ma3
# net_migration_ratio_cumu3
# net_migration_ratio_lag1
# taxable_income_growth_ma3
# taxable_income_growth_cumu3
# taxable_income_growth_lag1
# new_dwellings_ratio_ma3
# new_dwellings_ratio_cumu3
# new_dwellings_ratio_lag1
# unit_price_median_pct_chg_ma3
# unit_price_median_pct_chg_cumu3
# unit_price_median_pct_chg_lag1

# %%
X_engineered_columns
# Out:
# ['net_migration_ratio_ma3',
#  'net_migration_ratio_cumu3',
#  'net_migration_ratio_lag1',
#  'taxable_income_growth_ma3',
#  'taxable_income_growth_cumu3',
#  'taxable_income_growth_lag1',
#  'new_dwellings_ratio_ma3',
#  'new_dwellings_ratio_cumu3',
#  'new_dwellings_ratio_lag1',
#  'unit_price_median_pct_chg_ma3',
#  'unit_price_median_pct_chg_cumu3',
#  'unit_price_median_pct_chg_lag1']

# %%
df
# Out:
#       area_code                         area  year  population  count  \
# 18034     23441           Aichi-ken Agui-cho  2010     25695.0   41.0
# 17982     23441           Aichi-ken Agui-cho  2011     26248.0   40.0
# 17929     23441           Aichi-ken Agui-cho  2012     26793.0   45.0
# 17877     23441           Aichi-ken Agui-cho  2013     27128.0   44.0
# 17824     23441           Aichi-ken Agui-cho  2014     27518.0   50.0
# ...         ...                          ...   ...         ...    ...
# 15585     19205  Yamanashi-ken Yamanashi-shi  2017     33957.0   15.0
# 15560     19205  Yamanashi-ken Yamanashi-shi  2018     33789.0   14.0
# 15535     19205  Yamanashi-ken Yamanashi-shi  2019     33574.0   22.0
# 15510     19205  Yamanashi-ken Yamanashi-shi  2020     33435.0   16.0
# 15485     19205  Yamanashi-ken Yamanashi-shi  2021     33357.0   30.0
#
#        total_traded_area  taxable_income_per_taxpayer  \
# 18034             8265.0                  3213.665886
# 17982            11000.0                  3245.342254
# 17929             9585.0                  3270.662717
# 17877             8920.0                  3266.188636
# 17824            11620.0                  3326.902623
# ...                  ...                          ...
# 15585             5130.0                  2772.886669
# 15560             7400.0                  2832.607559
# 15535             8785.0                  2861.296683
# 15510             9255.0                  2870.243213
# 15485            13315.0                  2956.122862
#
#        taxable_income_per_taxpayer_growth  net_migration_ratio  \
# 18034                           -0.077565             0.021522
# 17982                            0.009857             0.020763
# 17929                            0.007802             0.012503
# 17877                           -0.001368             0.014376
# 17824                            0.018589             0.015953
# ...                                   ...                  ...
# 15585                            0.002362            -0.004947
# 15560                            0.021537            -0.006363
# 15535                            0.010128            -0.004140
# 15510                            0.003127            -0.000927
# 15485                            0.029921            -0.002338
#
#        taxable_income_growth  new_dwellings_ratio  unit_price_median_pct_chg  \
# 18034              -0.089172             0.000000                   0.062112
# 17982               0.023952             0.000000                   0.000000
# 17929               0.032618             0.000000                   0.026316
# 17877               0.013382             0.000000                  -0.037695
# 17824               0.031320             0.000000                  -0.004430
# ...                      ...                  ...                        ...
# 15585              -0.000603             0.009326                   0.970149
# 15560               0.028138             0.007798                  -0.439361
# 15535               0.019458             0.008447                   0.407036
# 15510               0.004950             0.008121                  -0.628406
# 15485               0.022114             0.011216                   0.628207
#
#        upcoming_unit_price_median_pct_chg  multiplier  \
# 18034                            0.000000    1.062112
# 17982                            0.026316    1.000000
# 17929                           -0.037695    1.026316
# 17877                           -0.004430    0.962305
# 17824                           -0.119682    0.995570
# ...                                   ...         ...
# 15585                           -0.439361    1.970149
# 15560                            0.407036    0.560639
# 15535                           -0.628406    1.407036
# 15510                            0.628207    0.371594
# 15485                            0.083744    1.628207
#
#        net_migration_ratio_ma3  net_migration_ratio_cumu3  \
# 18034                 0.021522                   1.021522
# 17982                 0.021143                   1.042732
# 17929                 0.018263                   1.055770
# 17877                 0.015881                   1.048385
# 17824                 0.014278                   1.043444
# ...                        ...                        ...
# 15585                -0.004990                   0.985102
# 15560                -0.004876                   0.985442
# 15535                -0.005150                   0.984628
# 15510                -0.003810                   0.988606
# 15485                -0.002469                   0.992610
#
#        net_migration_ratio_lag1  taxable_income_growth_ma3  \
# 18034                  0.000000                  -0.089172
# 17982                  0.021522                  -0.032610
# 17929                  0.020763                  -0.010867
# 17877                  0.012503                   0.023317
# 17824                  0.014376                   0.025773
# ...                         ...                        ...
# 15585                 -0.003317                   0.002522
# 15560                 -0.004947                   0.011771
# 15535                 -0.006363                   0.015664
# 15510                 -0.004140                   0.017515
# 15485                 -0.000927                   0.015507
#
#        taxable_income_growth_cumu3  taxable_income_growth_lag1  \
# 18034                     0.910828                    0.000000
# 17982                     0.932644                   -0.089172
# 17929                     0.963065                    0.023952
# 17877                     1.071500                    0.032618
# 17824                     1.079210                    0.013382
# ...                            ...                         ...
# 15585                     1.007565                    0.007778
# 15560                     1.035509                   -0.000603
# 15535                     1.047511                    0.028138
# 15510                     1.053331                    0.019458
# 15485                     1.047160                    0.004950
#
#        new_dwellings_ratio_ma3  new_dwellings_ratio_cumu3  \
# 18034                 0.000000                   1.000000
# 17982                 0.000000                   1.000000
# 17929                 0.000000                   1.000000
# 17877                 0.000000                   1.000000
# 17824                 0.000000                   1.000000
# ...                        ...                        ...
# 15585                 0.009868                   1.029898
# 15560                 0.009116                   1.027596
# 15535                 0.008524                   1.025789
# 15510                 0.008122                   1.024564
# 15485                 0.009261                   1.028039
#
#        new_dwellings_ratio_lag1  unit_price_median_pct_chg_ma3  \
# 18034                  0.000000                       0.062112
# 17982                  0.000000                       0.031056
# 17929                  0.000000                       0.029476
# 17877                  0.000000                      -0.003793
# 17824                  0.000000                      -0.005270
# ...                         ...                            ...
# 15585                  0.010223                       0.175164
# 15560                  0.009326                       0.147548
# 15535                  0.007798                       0.312608
# 15510                  0.008447                      -0.220244
# 15485                  0.008121                       0.135612
#
#        unit_price_median_pct_chg_cumu3  unit_price_median_pct_chg_lag1
# 18034                         1.062112                        0.000000
# 17982                         1.062112                        0.062112
# 17929                         1.090062                        0.000000
# 17877                         0.987629                        0.026316
# 17824                         0.983254                       -0.037695
# ...                                ...                             ...
# 15585                         1.156021                       -0.088145
# 15560                         1.007183                        0.970149
# 15535                         1.554131                       -0.439361
# 15510                         0.293128                        0.407036
# 15485                         0.851301                       -0.628406
#
# [20270 rows x 26 columns]

# %%
print(f"Initial Size: ", df.shape[0])
q = 0.01
filtered_df = df.copy()
filter_col = y_columns[0]
filtered_df = filtered_df[
    (filtered_df[filter_col] >= filtered_df[filter_col].quantile(q))
    & (filtered_df[filter_col] <= filtered_df[filter_col].quantile(1 - q))
]
print(f"Filtered Size: ", filtered_df.shape[0])
filtered_df.describe()
# Out:
# Initial Size:  20270
# Filtered Size:  19864
#                year    population         count  total_traded_area  \
# count  19864.000000  1.986400e+04  19864.000000       19864.000000
# mean    2014.540425  8.971883e+04     80.878574       21342.288814
# std        4.056016  2.127447e+05    204.030015       40406.805343
# min     2006.000000  1.479000e+03      1.000000          65.000000
# 25%     2011.000000  1.418475e+04      9.000000        4215.000000
# 50%     2015.000000  3.299450e+04     25.000000        9815.000000
# 75%     2018.000000  7.874025e+04     73.000000       21931.250000
# max     2021.000000  3.811873e+06   4358.000000      666150.000000
#
#        taxable_income_per_taxpayer  taxable_income_per_taxpayer_growth  \
# count                 19864.000000                        19864.000000
# mean                   2891.448711                            0.001864
# std                     565.400790                            0.031455
# min                    1989.133483                           -0.694693
# 25%                    2563.370989                           -0.008824
# 50%                    2786.840705                            0.002292
# 75%                    3087.482184                            0.012662
# max                   12667.020000                            0.915431
#
#        net_migration_ratio  taxable_income_growth  new_dwellings_ratio  \
# count         19864.000000           19864.000000         19864.000000
# mean             -0.003469               0.002374             0.007466
# std               0.006911               0.042392             0.008315
# min              -0.203379              -0.682739             0.000000
# 25%              -0.007142              -0.012071             0.000000
# 50%              -0.003494               0.005192             0.006218
# 75%               0.000059               0.020427             0.013245
# max               0.043446               0.882113             0.120270
#
#        unit_price_median_pct_chg  upcoming_unit_price_median_pct_chg  \
# count               19864.000000                        19864.000000
# mean                    0.152912                            0.099946
# std                     1.097823                            0.589221
# min                    -0.989961                           -0.821628
# 25%                    -0.202033                           -0.198948
# 50%                    -0.006145                           -0.004437
# 75%                     0.207230                            0.208791
# max                    55.809857                            4.115385
#
#          multiplier  net_migration_ratio_ma3  net_migration_ratio_cumu3  \
# count  19864.000000             19864.000000               19864.000000
# mean       1.152912                -0.003660                   0.990357
# std        1.097823                 0.006235                   0.017022
# min        0.010039                -0.160340                   0.590548
# 25%        0.797967                -0.007204                   0.980757
# 50%        0.993855                -0.003814                   0.990034
# 75%        1.207230                -0.000336                   0.999092
# max       56.809857                 0.038018                   1.114415
#
#        net_migration_ratio_lag1  taxable_income_growth_ma3  \
# count              19864.000000               19864.000000
# mean                  -0.003277                   0.000299
# std                    0.006602                   0.027876
# min                   -0.156526                  -0.682739
# 25%                   -0.006869                  -0.015660
# 50%                   -0.003004                   0.003288
# 75%                    0.000000                   0.015838
# max                    0.043446                   0.367086
#
#        taxable_income_growth_cumu3  taxable_income_growth_lag1  \
# count                 19864.000000                19864.000000
# mean                      1.003455                    0.000516
# std                       0.074157                    0.041237
# min                       0.199410                   -0.682739
# 25%                       0.961352                   -0.011699
# 50%                       1.008007                    0.001488
# 75%                       1.045605                    0.017077
# max                       2.188546                    0.882113
#
#        new_dwellings_ratio_ma3  new_dwellings_ratio_cumu3  \
# count             19864.000000               19864.000000
# mean                  0.007664                   1.021386
# std                   0.008343                   0.023829
# min                   0.000000                   1.000000
# 25%                   0.000000                   1.000000
# 50%                   0.006648                   1.016770
# 75%                   0.013699                   1.038460
# max                   0.092722                   1.303819
#
#        new_dwellings_ratio_lag1  unit_price_median_pct_chg_ma3  \
# count              19864.000000                   19864.000000
# mean                   0.007015                       0.156239
# std                    0.008351                       0.681592
# min                    0.000000                      -0.958065
# 25%                    0.000000                      -0.050768
# 50%                    0.004392                       0.027265
# 75%                    0.012892                       0.163622
# max                    0.120270                      31.333333
#
#        unit_price_median_pct_chg_cumu3  unit_price_median_pct_chg_lag1
# count                     19864.000000                    19864.000000
# mean                          1.122571                        0.151476
# std                           1.041585                        1.170662
# min                           0.013768                       -0.991268
# 25%                           0.748267                       -0.183315
# 50%                           0.968290                        0.000000
# 75%                           1.196598                        0.177092
# max                          33.238636                       55.809857

# %%
filtered_df.to_csv(model_ready_data_paths[f"xgb_{dataset_key}"], index=False)

# %%
area_code = 13102
test_df = filtered_df[filtered_df["area_code"] == area_code]
test_df[["year", metric_pct_chg, upcoming_metric_pct_chg]]
# Out:
#       year  unit_price_median_pct_chg  upcoming_unit_price_median_pct_chg
# 3275  2006                  -0.020641                            0.394034
# 3219  2007                   0.394034                           -0.133005
# 3162  2008                  -0.133005                           -0.253898
# 3104  2009                  -0.253898                           -0.124004
# 3047  2010                  -0.124004                           -0.129796
# 2992  2011                  -0.129796                            0.060761
# 2935  2012                   0.060761                            0.064558
# 2876  2013                   0.064558                            0.112918
# 2818  2014                   0.112918                            0.197544
# 2761  2015                   0.197544                            0.262745
# 2703  2016                   0.262745                            0.125224
# 2645  2017                   0.125224                           -0.040460
# 2588  2018                  -0.040460                            0.124654
# 2530  2019                   0.124654                           -0.011111
# 2471  2020                  -0.011111                           -0.122304
# 2413  2021                  -0.122304                            0.434898

# %%
test_year = 2021
presentation_df = filtered_df[filtered_df["area_code"].astype(int) // 1000 == 13]
presentation_df = presentation_df[presentation_df["year"] == test_year]
presentation_df = presentation_df.sort_index(axis=1)
presentation_df["upcoming_return"] = presentation_df[upcoming_metric_pct_chg]
presentation_df = presentation_df.sort_values(by=upcoming_metric_pct_chg, ascending=False).reset_index(drop=True)

drop_columns = [upcoming_metric_pct_chg, "area_code"]
presentation_df.drop(columns=drop_columns).style.background_gradient(cmap="cividis")
# Out:
# <style type="text/css">
# #T_cfa8f_row0_col1, #T_cfa8f_row2_col22, #T_cfa8f_row3_col18, #T_cfa8f_row50_col16 {
#   background-color: #002a5f;
#   color: #f1f1f1;
# }
# #T_cfa8f_row0_col2, #T_cfa8f_row0_col19, #T_cfa8f_row5_col13, #T_cfa8f_row46_col10 {
#   background-color: #b7a96e;
#   color: #f1f1f1;
# }
# #T_cfa8f_row0_col3, #T_cfa8f_row6_col5, #T_cfa8f_row42_col5, #T_cfa8f_row47_col5 {
#   background-color: #6b6d72;
#   color: #f1f1f1;
# }
# #T_cfa8f_row0_col4, #T_cfa8f_row0_col12, #T_cfa8f_row37_col12, #T_cfa8f_row50_col10 {
#   background-color: #555c6d;
#   color: #f1f1f1;
# }
# #T_cfa8f_row0_col5, #T_cfa8f_row3_col3, #T_cfa8f_row7_col8, #T_cfa8f_row22_col10, #T_cfa8f_row31_col8, #T_cfa8f_row39_col15, #T_cfa8f_row42_col8 {
#   background-color: #5e626e;
#   color: #f1f1f1;
# }
# #T_cfa8f_row0_col6, #T_cfa8f_row7_col3, #T_cfa8f_row11_col8, #T_cfa8f_row13_col8, #T_cfa8f_row13_col9, #T_cfa8f_row15_col7, #T_cfa8f_row19_col7, #T_cfa8f_row27_col7 {
#   background-color: #565c6d;
#   color: #f1f1f1;
# }
# #T_cfa8f_row0_col7, #T_cfa8f_row0_col8, #T_cfa8f_row0_col9, #T_cfa8f_row0_col10, #T_cfa8f_row0_col23, #T_cfa8f_row1_col23, #T_cfa8f_row2_col23, #T_cfa8f_row3_col12, #T_cfa8f_row3_col17, #T_cfa8f_row3_col23, #T_cfa8f_row4_col23, #T_cfa8f_row5_col23, #T_cfa8f_row6_col23, #T_cfa8f_row7_col23, #T_cfa8f_row8_col23, #T_cfa8f_row9_col23, #T_cfa8f_row10_col1, #T_cfa8f_row10_col7, #T_cfa8f_row10_col8, #T_cfa8f_row10_col9, #T_cfa8f_row10_col10, #T_cfa8f_row10_col11, #T_cfa8f_row10_col13, #T_cfa8f_row10_col15, #T_cfa8f_row10_col23, #T_cfa8f_row11_col23, #T_cfa8f_row12_col23, #T_cfa8f_row13_col23, #T_cfa8f_row14_col23, #T_cfa8f_row15_col23, #T_cfa8f_row16_col5, #T_cfa8f_row16_col23, #T_cfa8f_row17_col23, #T_cfa8f_row18_col3, #T_cfa8f_row18_col23, #T_cfa8f_row19_col23, #T_cfa8f_row20_col23, #T_cfa8f_row21_col7, #T_cfa8f_row21_col8, #T_cfa8f_row21_col9, #T_cfa8f_row21_col10, #T_cfa8f_row21_col23, #T_cfa8f_row22_col22, #T_cfa8f_row22_col23, #T_cfa8f_row23_col23, #T_cfa8f_row24_col23, #T_cfa8f_row25_col23, #T_cfa8f_row26_col23, #T_cfa8f_row27_col23, #T_cfa8f_row28_col23, #T_cfa8f_row29_col23, #T_cfa8f_row30_col23, #T_cfa8f_row31_col23, #T_cfa8f_row32_col23, #T_cfa8f_row33_col23, #T_cfa8f_row34_col23, #T_cfa8f_row35_col23, #T_cfa8f_row36_col23, #T_cfa8f_row37_col23, #T_cfa8f_row38_col23, #T_cfa8f_row39_col23, #T_cfa8f_row40_col23, #T_cfa8f_row41_col23, #T_cfa8f_row42_col23, #T_cfa8f_row43_col23, #T_cfa8f_row44_col23, #T_cfa8f_row45_col23, #T_cfa8f_row46_col14, #T_cfa8f_row46_col23, #T_cfa8f_row47_col23, #T_cfa8f_row48_col23, #T_cfa8f_row49_col23, #T_cfa8f_row50_col23, #T_cfa8f_row51_col1, #T_cfa8f_row51_col2, #T_cfa8f_row51_col7, #T_cfa8f_row51_col8, #T_cfa8f_row51_col9, #T_cfa8f_row51_col10, #T_cfa8f_row51_col11, #T_cfa8f_row51_col16, #T_cfa8f_row51_col19, #T_cfa8f_row51_col20, #T_cfa8f_row51_col22, #T_cfa8f_row51_col23, #T_cfa8f_row52_col7, #T_cfa8f_row52_col8, #T_cfa8f_row52_col9, #T_cfa8f_row52_col10, #T_cfa8f_row52_col23, #T_cfa8f_row53_col4, #T_cfa8f_row53_col5, #T_cfa8f_row53_col6, #T_cfa8f_row53_col7, #T_cfa8f_row53_col8, #T_cfa8f_row53_col9, #T_cfa8f_row53_col10, #T_cfa8f_row53_col18, #T_cfa8f_row53_col21, #T_cfa8f_row53_col23, #T_cfa8f_row53_col24 {
#   background-color: #00224e;
#   color: #f1f1f1;
# }
# #T_cfa8f_row0_col11, #T_cfa8f_row0_col16, #T_cfa8f_row46_col12 {
#   background-color: #00285b;
#   color: #f1f1f1;
# }
# #T_cfa8f_row0_col13, #T_cfa8f_row16_col13, #T_cfa8f_row21_col15, #T_cfa8f_row29_col1, #T_cfa8f_row49_col4 {
#   background-color: #3f4c6c;
#   color: #f1f1f1;
# }
# #T_cfa8f_row0_col14, #T_cfa8f_row4_col20, #T_cfa8f_row29_col8, #T_cfa8f_row32_col13, #T_cfa8f_row43_col6, #T_cfa8f_row48_col9 {
#   background-color: #7e7c78;
#   color: #f1f1f1;
# }
# #T_cfa8f_row0_col15, #T_cfa8f_row6_col13, #T_cfa8f_row9_col12, #T_cfa8f_row10_col5, #T_cfa8f_row49_col6 {
#   background-color: #404c6c;
#   color: #f1f1f1;
# }
# #T_cfa8f_row0_col17, #T_cfa8f_row1_col16, #T_cfa8f_row23_col13, #T_cfa8f_row25_col10, #T_cfa8f_row28_col6 {
#   background-color: #777776;
#   color: #f1f1f1;
# }
# #T_cfa8f_row0_col18, #T_cfa8f_row11_col1, #T_cfa8f_row11_col18, #T_cfa8f_row12_col11, #T_cfa8f_row24_col16, #T_cfa8f_row42_col11, #T_cfa8f_row45_col16 {
#   background-color: #003070;
#   color: #f1f1f1;
# }
# #T_cfa8f_row0_col20, #T_cfa8f_row2_col17, #T_cfa8f_row6_col6, #T_cfa8f_row8_col7, #T_cfa8f_row20_col5, #T_cfa8f_row24_col11, #T_cfa8f_row25_col9, #T_cfa8f_row38_col7, #T_cfa8f_row42_col9 {
#   background-color: #787877;
#   color: #f1f1f1;
# }
# #T_cfa8f_row0_col21, #T_cfa8f_row16_col21, #T_cfa8f_row20_col12, #T_cfa8f_row25_col3, #T_cfa8f_row26_col21, #T_cfa8f_row39_col21, #T_cfa8f_row49_col3 {
#   background-color: #48526c;
#   color: #f1f1f1;
# }
# #T_cfa8f_row0_col22, #T_cfa8f_row43_col11, #T_cfa8f_row44_col16, #T_cfa8f_row46_col1 {
#   background-color: #003170;
#   color: #f1f1f1;
# }
# #T_cfa8f_row0_col24, #T_cfa8f_row1_col12, #T_cfa8f_row1_col13, #T_cfa8f_row1_col15, #T_cfa8f_row2_col7, #T_cfa8f_row2_col8, #T_cfa8f_row2_col10, #T_cfa8f_row2_col14, #T_cfa8f_row3_col4, #T_cfa8f_row3_col6, #T_cfa8f_row5_col9, #T_cfa8f_row21_col3, #T_cfa8f_row25_col11, #T_cfa8f_row33_col1, #T_cfa8f_row44_col18, #T_cfa8f_row46_col16, #T_cfa8f_row49_col20, #T_cfa8f_row51_col5, #T_cfa8f_row52_col17, #T_cfa8f_row52_col21, #T_cfa8f_row52_col22, #T_cfa8f_row53_col2, #T_cfa8f_row53_col19 {
#   background-color: #fee838;
#   color: #000000;
# }
# #T_cfa8f_row1_col1, #T_cfa8f_row6_col11, #T_cfa8f_row11_col11, #T_cfa8f_row31_col22, #T_cfa8f_row37_col16, #T_cfa8f_row39_col1 {
#   background-color: #003171;
#   color: #f1f1f1;
# }
# #T_cfa8f_row1_col2, #T_cfa8f_row1_col19, #T_cfa8f_row5_col20, #T_cfa8f_row7_col2, #T_cfa8f_row7_col19, #T_cfa8f_row13_col17, #T_cfa8f_row23_col15, #T_cfa8f_row24_col17, #T_cfa8f_row24_col18, #T_cfa8f_row25_col4, #T_cfa8f_row37_col5, #T_cfa8f_row37_col17 {
#   background-color: #797977;
#   color: #f1f1f1;
# }
# #T_cfa8f_row1_col3, #T_cfa8f_row10_col12, #T_cfa8f_row18_col15, #T_cfa8f_row24_col14, #T_cfa8f_row28_col4, #T_cfa8f_row33_col10, #T_cfa8f_row35_col12, #T_cfa8f_row48_col13, #T_cfa8f_row53_col17 {
#   background-color: #767676;
#   color: #f1f1f1;
# }
# #T_cfa8f_row1_col4 {
#   background-color: #d6c35d;
#   color: #000000;
# }
# #T_cfa8f_row1_col5, #T_cfa8f_row4_col12, #T_cfa8f_row11_col15, #T_cfa8f_row14_col14, #T_cfa8f_row15_col3, #T_cfa8f_row36_col10 {
#   background-color: #807f78;
#   color: #f1f1f1;
# }
# #T_cfa8f_row1_col6 {
#   background-color: #d7c45c;
#   color: #000000;
# }
# #T_cfa8f_row1_col7, #T_cfa8f_row13_col15, #T_cfa8f_row22_col8, #T_cfa8f_row28_col5, #T_cfa8f_row37_col7 {
#   background-color: #5c616e;
#   color: #f1f1f1;
# }
# #T_cfa8f_row1_col8, #T_cfa8f_row2_col2, #T_cfa8f_row2_col19, #T_cfa8f_row9_col8, #T_cfa8f_row11_col4, #T_cfa8f_row22_col6, #T_cfa8f_row48_col6, #T_cfa8f_row49_col12, #T_cfa8f_row50_col17 {
#   background-color: #848279;
#   color: #f1f1f1;
# }
# #T_cfa8f_row1_col9, #T_cfa8f_row17_col17, #T_cfa8f_row19_col6, #T_cfa8f_row20_col24, #T_cfa8f_row23_col2, #T_cfa8f_row23_col19, #T_cfa8f_row31_col17, #T_cfa8f_row39_col7, #T_cfa8f_row40_col18 {
#   background-color: #aca172;
#   color: #f1f1f1;
# }
# #T_cfa8f_row1_col10, #T_cfa8f_row9_col10, #T_cfa8f_row11_col6, #T_cfa8f_row14_col13, #T_cfa8f_row24_col20, #T_cfa8f_row40_col12, #T_cfa8f_row43_col14, #T_cfa8f_row45_col7, #T_cfa8f_row45_col13 {
#   background-color: #868379;
#   color: #f1f1f1;
# }
# #T_cfa8f_row1_col11, #T_cfa8f_row2_col16, #T_cfa8f_row9_col22, #T_cfa8f_row14_col16, #T_cfa8f_row16_col14, #T_cfa8f_row18_col1, #T_cfa8f_row21_col22, #T_cfa8f_row38_col3, #T_cfa8f_row40_col16, #T_cfa8f_row50_col22 {
#   background-color: #2e416d;
#   color: #f1f1f1;
# }
# #T_cfa8f_row1_col14, #T_cfa8f_row30_col4, #T_cfa8f_row44_col3 {
#   background-color: #9f9775;
#   color: #f1f1f1;
# }
# #T_cfa8f_row1_col17 {
#   background-color: #fee434;
#   color: #000000;
# }
# #T_cfa8f_row1_col18, #T_cfa8f_row4_col22, #T_cfa8f_row11_col22, #T_cfa8f_row39_col11 {
#   background-color: #002f6d;
#   color: #f1f1f1;
# }
# #T_cfa8f_row1_col20, #T_cfa8f_row3_col7, #T_cfa8f_row9_col3, #T_cfa8f_row12_col10, #T_cfa8f_row24_col7, #T_cfa8f_row25_col8, #T_cfa8f_row30_col7, #T_cfa8f_row40_col6, #T_cfa8f_row46_col9, #T_cfa8f_row48_col1 {
#   bac

# %%
# sort by median and weighted median to see the difference in ordering.
# Try to find the best metric to use
