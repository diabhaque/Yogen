# %%
import warnings

import numpy as np
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt

from jre_utils.datapath import factor_data_paths, get_derived_csv_path, model_ready_data_paths
from jre_utils.config import asset_types, statistics, area_levels, period_cols
from jre_utils.process import get_most_active_municipalities

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %%
period = "yearly"
area_level = "municipality"
asset_type = "building"
statistic = "median"

granularity_columns = area_levels[area_level]["columns"]
group_by_columns = granularity_columns + [period_cols[period]]
display_columns = list(statistics[statistic].keys())

metric = asset_types[asset_type]["metric"]
metric_pct_chg = asset_types[asset_type]["metric_pct_chg"]
upcoming_metric_pct_chg = "Upcoming" + metric_pct_chg

core_path = get_derived_csv_path(period, area_level, asset_type, statistic)
population_path = factor_data_paths["processed"]["population"]["municipality"]
migration_path = factor_data_paths["processed"]["migration"]["municipality"]
taxable_income_path = factor_data_paths["processed"]["taxable_income"]["municipality"]
new_dwellings_path = factor_data_paths["processed"]["new_dwellings"]["municipality"]

# %%
df = pd.read_csv(core_path)

population_df = pd.read_csv(population_path)
migration_df = pd.read_csv(migration_path)
taxable_income_df = pd.read_csv(taxable_income_path)
new_dwellings_df = pd.read_csv(new_dwellings_path)

df = (
    df.merge(population_df, on=group_by_columns, how="left")
    .merge(migration_df, on=group_by_columns, how="left")
    .merge(taxable_income_df, on=group_by_columns, how="left")
    .merge(new_dwellings_df, on=group_by_columns, how="left")
)

# %%
# prepare metrics
df = df.sort_values(by=group_by_columns, ascending=True)
df[metric_pct_chg] = df.groupby(granularity_columns)[metric].pct_change()

# set up target variables
df[upcoming_metric_pct_chg] = df.groupby(granularity_columns)[metric_pct_chg].shift(-1)

# time box
start_year = 2005
end_year = 2023

df = df[(df["year"] >= start_year) & (df["year"] <= end_year)]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30339 entries, 19363 to 17393
# Data columns (total 19 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Prefecture                          30339 non-null  object
#  1   Municipality                        30339 non-null  object
#  2   year                                30339 non-null  int64
#  3   TradePricePerArea                   30339 non-null  float64
#  4   UnitPrice                           0 non-null      float64
#  5   Count                               30339 non-null  int64
#  6   population                          24235 non-null  float64
#  7   net_migration_ratio                 24235 non-null  float64
#  8   taxable_income                      23202 non-null  float64
#  9   taxpayer_count                      23202 non-null  float64
#  10  taxable_income_per_taxpayer         23202 non-null  float64
#  11  taxable_income_growth               23202 non-null  float64
#  12  taxable_income_per_taxpayer_growth  23202 non-null  float64
#  13  area                                11564 non-null  object
#  14  new_dwellings                       11564 non-null  float64
#  15  existing_dwellings                  11564 non-null  float64
#  16  new_dwellings_ratio                 11564 non-null  float64
#  17  TradePricePctChg                    28464 non-null  float64
#  18  UpcomingTradePricePctChg            28464 non-null  float64
# dtypes: float64(14), int64(2), object(3)
# memory usage: 4.6+ MB

# %%
# most frequent municipalities
# skip this and build custom cost function using count as parameter. The lower the count, the lower the cost.

# df = get_most_active_municipalities(df, n=800)
# df = df[df["Count"] >= 10]

# %%
y_columns = [upcoming_metric_pct_chg]

X_categorical_columns = ["Prefecture", "Municipality"]

X_basic_columns = [
    "year",
    "population",
    "Count",
    "taxable_income_per_taxpayer",
    "taxable_income_per_taxpayer_growth",
]

X_engineering_columns = [
    "net_migration_ratio",
    "taxable_income_growth",
    "new_dwellings_ratio",
    metric_pct_chg,
]

initial_columns = (
    X_categorical_columns + X_basic_columns + X_engineering_columns + y_columns
)

df = df[initial_columns]
df[X_categorical_columns] = df[X_categorical_columns].astype("category")
df = df.dropna()

# %%
lag = 1

X_engineered_columns = []

for col in X_engineering_columns:
    df["multiplier"] = df[col] + 1
    df[f"{col}_ma3"] = df.groupby(granularity_columns)[col].transform(
        lambda x: x.rolling(3, 1).mean()
    )
    df[f"{col}_cumu3"] = df.groupby(granularity_columns)["multiplier"].transform(
        lambda x: x.rolling(3, 1).apply(np.prod, raw=True)
    )

    X_engineered_columns.append(f"{col}_ma3")
    X_engineered_columns.append(f"{col}_cumu3")
    print(f"{col}_ma3")
    print(f"{col}_cumu3")

    for i in range(1, lag + 1):
        df[f"{col}_lag{i}"] = df.groupby(granularity_columns)[col].shift(i)
        X_engineered_columns.append(f"{col}_lag{i}")
        print(f"{col}_lag{i}")

df[X_engineered_columns] = df[X_engineered_columns].fillna(0)
# Out:
# net_migration_ratio_ma3
# net_migration_ratio_cumu3
# net_migration_ratio_lag1
# taxable_income_growth_ma3
# taxable_income_growth_cumu3
# taxable_income_growth_lag1
# new_dwellings_ratio_ma3
# new_dwellings_ratio_cumu3
# new_dwellings_ratio_lag1
# TradePricePctChg_ma3
# TradePricePctChg_cumu3
# TradePricePctChg_lag1

# %%
df
# Out:
#       Prefecture Municipality  year  population  Count  \
# 19383      Aichi        Aisai  2010     61910.0     51
# 19384      Aichi        Aisai  2011     62000.0     43
# 19385      Aichi        Aisai  2012     61807.0     42
# 19386      Aichi        Aisai  2013     61851.0     36
# 19387      Aichi        Aisai  2014     61710.0     46
# ...          ...          ...   ...         ...    ...
# 17387  Yamanashi    Yamanashi  2017     33957.0     15
# 17388  Yamanashi    Yamanashi  2018     33789.0     14
# 17389  Yamanashi    Yamanashi  2019     33574.0     22
# 17390  Yamanashi    Yamanashi  2020     33435.0     16
# 17391  Yamanashi    Yamanashi  2021     33357.0     30
#
#        taxable_income_per_taxpayer  taxable_income_per_taxpayer_growth  \
# 19383                  2982.171416                           -0.066436
# 19384                  2977.500230                           -0.001566
# 19385                  2968.945417                           -0.002873
# 19386                  2960.406212                           -0.002876
# 19387                  2996.514481                            0.012197
# ...                            ...                                 ...
# 17387                  2772.886669                            0.002362
# 17388                  2832.607559                            0.021537
# 17389                  2861.296683                            0.010128
# 17390                  2870.243213                            0.003127
# 17391                  2956.122862                            0.029921
#
#        net_migration_ratio  taxable_income_growth  new_dwellings_ratio  \
# 19383             0.001454              -0.095355             0.014016
# 19384            -0.003113              -0.011972             0.012682
# 19385             0.000712               0.001476             0.014550
# 19386            -0.002280               0.000891             0.011411
# 19387            -0.001912               0.004293             0.010975
# ...                    ...                    ...                  ...
# 17387            -0.004947              -0.000603             0.009326
# 17388            -0.006363               0.028138             0.007798
# 17389            -0.004140               0.019458             0.008447
# 17390            -0.000927               0.004950             0.008121
# 17391            -0.002338               0.022114             0.011216
#
#        TradePricePctChg  UpcomingTradePricePctChg  multiplier  \
# 19383         -0.282297                  0.000000    0.717703
# 19384          0.000000                  0.100000    1.000000
# 19385          0.100000                 -0.079637    1.100000
# 19386         -0.079637                 -0.163846    0.920363
# 19387         -0.163846                  0.004109    0.836154
# ...                 ...                       ...         ...
# 17387          0.970149                 -0.439361    1.970149
# 17388         -0.439361                  0.407036    0.560639
# 17389          0.407036                 -0.628406    1.407036
# 17390         -0.628406                  0.628207    0.371594
# 17391          0.628207                  0.083744    1.628207
#
#        net_migration_ratio_ma3  net_migration_ratio_cumu3  \
# 19383                 0.001454                   1.001454
# 19384                -0.000830                   0.998336
# 19385                -0.000316                   0.999047
# 19386                -0.001560                   0.995323
# 19387                -0.001160                   0.996521
# ...                        ...                        ...
# 17387                -0.004990                   0.985102
# 17388                -0.004876                   0.985442
# 17389                -0.005150                   0.984628
# 17390                -0.003810                   0.988606
# 17391                -0.002469                   0.992610
#
#        net_migration_ratio_lag1  taxable_income_growth_ma3  \
# 19383                  0.000000                  -0.095355
# 19384                  0.001454                  -0.053663
# 19385                 -0.003113                  -0.035284
# 19386                  0.000712                  -0.003202
# 19387                 -0.002280                   0.002220
# ...                         ...                        ...
# 17387                 -0.003317                   0.002522
# 17388                 -0.004947                   0.011771
# 17389                 -0.006363                   0.015664
# 17390                 -0.004140                   0.017515
# 17391                 -0.000927                   0.015507
#
#        taxable_income_growth_cumu3  taxable_income_growth_lag1  \
# 19383                     0.904645                    0.000000
# 19384                     0.893815                   -0.095355
# 19385                     0.895134                   -0.011972
# 19386                     0.990368                    0.001476
# 19387                     1.006671                    0.000891
# ...                            ...                         ...
# 17387                     1.007565                    0.007778
# 17388                     1.035509                   -0.000603
# 17389                     1.047511                    0.028138
# 17390                     1.053331                    0.019458
# 17391                     1.047160                    0.004950
#
#        new_dwellings_ratio_ma3  new_dwellings_ratio_cumu3  \
# 19383                 0.014016                   1.014016
# 19384                 0.013349                   1.026876
# 19385                 0.013749                   1.041817
# 19386                 0.012881                   1.039141
# 19387                 0.012312                   1.037389
# ...                        ...                        ...
# 17387                 0.009868                   1.029898
# 17388                 0.009116                   1.027596
# 17389                 0.008524                   1.025789
# 17390                 0.008122                   1.024564
# 17391                 0.009261                   1.028039
#
#        new_dwellings_ratio_lag1  TradePricePctChg_ma3  TradePricePctChg_cumu3  \
# 19383                  0.000000             -0.282297                0.717703
# 19384                  0.014016             -0.141148                0.717703
# 19385                  0.012682             -0.060766                0.789474
# 19386                  0.014550              0.006788                1.012399
# 19387                  0.011411             -0.047828                0.846522
# ...                         ...                   ...                     ...
# 17387                  0.010223              0.175164                1.156021
# 17388                  0.009326              0.147548                1.007183
# 17389                  0.007798              0.312608                1.554131
# 17390                  0.008447             -0.220244                0.293128
# 17391                  0.008121              0.135612                0.851301
#
#        TradePricePctChg_lag1
# 19383               0.000000
# 19384              -0.282297
# 19385               0.000000
# 19386               0.100000
# 19387              -0.079637
# ...                      ...
# 17387              -0.088145
# 17388               0.970149
# 17389              -0.439361
# 17390               0.407036
# 17391              -0.628406
#
# [10701 rows x 25 columns]

# %%
print(f"Initial Size: ", df.shape[0])
q = 0.01
filtered_df = df.copy()
filter_col = y_columns[0]
filtered_df = filtered_df[
    (filtered_df[filter_col] >= filtered_df[filter_col].quantile(q))
    & (filtered_df[filter_col] <= filtered_df[filter_col].quantile(1 - q))
]
print(f"Filtered Size: ", filtered_df.shape[0])
filtered_df.describe()
# Out:
# Initial Size:  10701
# Filtered Size:  10487
#                year    population         Count  taxable_income_per_taxpayer  \
# count  10487.000000  1.048700e+04  10487.000000                 10487.000000
# mean    2014.462001  1.180853e+05    103.806618                  3022.698681
# std        4.075304  1.376232e+05    118.645472                   668.935295
# min     2006.000000  2.961000e+03      1.000000                  2053.240341
# 25%     2011.000000  4.139450e+04     29.000000                  2647.120051
# 50%     2015.000000  6.860300e+04     62.000000                  2893.738632
# 75%     2018.000000  1.334385e+05    126.000000                  3218.537565
# max     2021.000000  1.540632e+06    886.000000                 12667.020000
#
#        taxable_income_per_taxpayer_growth  net_migration_ratio  \
# count                        10487.000000         10487.000000
# mean                             0.001225            -0.002433
# std                              0.022551             0.005506
# min                             -0.294513            -0.058973
# 25%                             -0.007598            -0.005702
# 50%                              0.002385            -0.002634
# 75%                              0.011454             0.000399
# max                              0.409227             0.043446
#
#        taxable_income_growth  new_dwellings_ratio  TradePricePctChg  \
# count           10487.000000         10487.000000      10487.000000
# mean                0.003387             0.013322          0.036578
# std                 0.033416             0.006797          0.473326
# min                -0.398456             0.000000         -0.886667
# 25%                -0.008249             0.008860         -0.138136
# 50%                 0.006771             0.012416         -0.005405
# 75%                 0.019931             0.016489          0.128411
# max                 0.440856             0.120270         31.333333
#
#        UpcomingTradePricePctChg    multiplier  net_migration_ratio_ma3  \
# count              10487.000000  10487.000000             10487.000000
# mean                   0.025494      1.036578                -0.002612
# std                    0.287359      0.473326                 0.005271
# min                   -0.614716      0.113333                -0.027463
# 25%                   -0.134442      0.861864                -0.005823
# 50%                   -0.003605      0.994595                -0.002880
# 75%                    0.128733      1.128411                 0.000064
# max                    1.459250     32.333333                 0.038018
#
#        net_migration_ratio_cumu3  net_migration_ratio_lag1  \
# count               10487.000000              10487.000000
# mean                    0.993211                 -0.002299
# std                     0.014421                  0.005398
# min                     0.920712                 -0.058973
# 25%                     0.984274                 -0.005501
# 50%                     0.992599                 -0.002177
# 75%                     1.000151                  0.000077
# max                     1.105401                  0.043446
#
#        taxable_income_growth_ma3  taxable_income_growth_cumu3  \
# count               10487.000000                 10487.000000
# mean                    0.001617                     1.006916
# std                     0.024317                     0.065955
# min                    -0.201696                     0.483597
# 25%                    -0.012679                     0.968971
# 50%                     0.005167                     1.013121
# 75%                     0.016362                     1.047582
# max                     0.221486                     1.809814
#
#        taxable_income_growth_lag1  new_dwellings_ratio_ma3  \
# count                10487.000000             10487.000000
# mean                     0.001669                 0.013696
# std                      0.032262                 0.006509
# min                     -0.398456                 0.000762
# 25%                     -0.008042                 0.009287
# 50%                      0.003411                 0.012912
# 75%                      0.017098                 0.016897
# max                      0.440856                 0.091613
#
#        new_dwellings_ratio_cumu3  new_dwellings_ratio_lag1  \
# count               10487.000000              10487.000000
# mean                    1.038157                  0.012513
# std                     0.019467                  0.007483
# min                     1.000980                  0.000000
# 25%                     1.024581                  0.007940
# 50%                     1.036014                  0.012021
# 75%                     1.048347                  0.016294
# max                     1.299733                  0.095865
#
#        TradePricePctChg_ma3  TradePricePctChg_cumu3  TradePricePctChg_lag1
# count          10487.000000            10487.000000           10487.000000
# mean               0.038656                1.025911               0.035848
# std                0.418574                0.665836               0.468031
# min               -0.886667                0.029330              -0.973874
# 25%               -0.049417                0.817270              -0.125091
# 50%                0.008819                0.973214               0.000000
# 75%                0.076782                1.133027               0.111764
# max               31.333333               32.666667              31.333333

# %%
filtered_df.to_csv(model_ready_data_paths["basic"], index=False)

# %%
test_prefecture, test_municipality = "Tokyo", "Minato"
test_df = filtered_df[(filtered_df["Prefecture"] == test_prefecture) & (filtered_df["Municipality"] == test_municipality)]
test_df[["year", metric_pct_chg, upcoming_metric_pct_chg]]
# Out:
#       year  TradePricePctChg  UpcomingTradePricePctChg
# 3076  2006          0.467742                  0.027027
# 3077  2007          0.027027                  0.010341
# 3078  2008          0.010341                 -0.413008
# 3079  2009         -0.413008                 -0.071642
# 3080  2010         -0.071642                  0.052466
# 3081  2011          0.052466                 -0.041267
# 3082  2012         -0.041267                  0.095410
# 3083  2013          0.095410                  0.053292
# 3084  2014          0.053292                  0.160000
# 3085  2015          0.160000                  0.115481
# 3086  2016          0.115481                  0.190725
# 3087  2017          0.190725                  0.119491
# 3088  2018          0.119491                 -0.154545
# 3089  2019         -0.154545                  0.041667
# 3090  2020          0.041667                  0.213151
# 3091  2021          0.213151                 -0.010841

# %%
test_year = 2021
test_prefecture = "Tokyo"
presentation_df = df[(df["Prefecture"] == test_prefecture) & (df["year"] == test_year)]
presentation_df = presentation_df.sort_index(axis=1)
presentation_df["upcoming_return"] = tokyo_df["UpcomingTradePricePctChg"]
presentation_df = presentation_df.sort_values(by=upcoming_metric_pct_chg, ascending=False).reset_index(drop=True)

drop_columns = ["UpcomingTradePricePctChg", "year", "Prefecture"]
presentation_df.drop(columns=drop_columns).style.background_gradient(cmap="cividis")
# Out:
# <style type="text/css">
# #T_f64ea_row0_col0, #T_f64ea_row2_col18, #T_f64ea_row15_col15, #T_f64ea_row21_col20, #T_f64ea_row29_col11, #T_f64ea_row36_col0, #T_f64ea_row42_col20 {
#   background-color: #002a61;
#   color: #f1f1f1;
# }
# #T_f64ea_row0_col2, #T_f64ea_row0_col6, #T_f64ea_row2_col16, #T_f64ea_row2_col21, #T_f64ea_row5_col17, #T_f64ea_row5_col19, #T_f64ea_row8_col4, #T_f64ea_row9_col11, #T_f64ea_row14_col0, #T_f64ea_row14_col9, #T_f64ea_row14_col15, #T_f64ea_row14_col17, #T_f64ea_row14_col19, #T_f64ea_row16_col7, #T_f64ea_row19_col3, #T_f64ea_row19_col5, #T_f64ea_row36_col20, #T_f64ea_row43_col18, #T_f64ea_row47_col8, #T_f64ea_row47_col10, #T_f64ea_row47_col12, #T_f64ea_row47_col13, #T_f64ea_row47_col14, #T_f64ea_row47_col15, #T_f64ea_row47_col20 {
#   background-color: #00224e;
#   color: #f1f1f1;
# }
# #T_f64ea_row0_col3, #T_f64ea_row28_col20, #T_f64ea_row30_col20, #T_f64ea_row47_col17 {
#   background-color: #1a386f;
#   color: #f1f1f1;
# }
# #T_f64ea_row0_col4, #T_f64ea_row4_col2, #T_f64ea_row4_col6, #T_f64ea_row26_col7, #T_f64ea_row37_col8, #T_f64ea_row37_col10 {
#   background-color: #4f576c;
#   color: #f1f1f1;
# }
# #T_f64ea_row0_col5, #T_f64ea_row10_col13, #T_f64ea_row15_col12, #T_f64ea_row26_col20, #T_f64ea_row46_col11 {
#   background-color: #2b406d;
#   color: #f1f1f1;
# }
# #T_f64ea_row0_col7 {
#   background-color: #9a9376;
#   color: #f1f1f1;
# }
# #T_f64ea_row0_col8, #T_f64ea_row0_col10 {
#   background-color: #cbb965;
#   color: #000000;
# }
# #T_f64ea_row0_col9, #T_f64ea_row3_col18, #T_f64ea_row8_col7, #T_f64ea_row20_col2, #T_f64ea_row20_col6, #T_f64ea_row28_col21, #T_f64ea_row36_col4 {
#   background-color: #999277;
#   color: #f1f1f1;
# }
# #T_f64ea_row0_col11, #T_f64ea_row1_col2, #T_f64ea_row1_col6, #T_f64ea_row11_col17, #T_f64ea_row20_col14 {
#   background-color: #213b6e;
#   color: #f1f1f1;
# }
# #T_f64ea_row0_col12, #T_f64ea_row3_col4, #T_f64ea_row8_col12, #T_f64ea_row16_col3, #T_f64ea_row17_col18, #T_f64ea_row23_col13, #T_f64ea_row32_col5, #T_f64ea_row33_col10, #T_f64ea_row39_col2, #T_f64ea_row39_col6, #T_f64ea_row44_col11, #T_f64ea_row46_col3 {
#   background-color: #61656f;
#   color: #f1f1f1;
# }
# #T_f64ea_row0_col13, #T_f64ea_row15_col16, #T_f64ea_row18_col18 {
#   background-color: #969077;
#   color: #f1f1f1;
# }
# #T_f64ea_row0_col14, #T_f64ea_row8_col14, #T_f64ea_row10_col16, #T_f64ea_row12_col3, #T_f64ea_row14_col3, #T_f64ea_row19_col8, #T_f64ea_row44_col16, #T_f64ea_row45_col8 {
#   background-color: #62656f;
#   color: #f1f1f1;
# }
# #T_f64ea_row0_col15, #T_f64ea_row17_col4, #T_f64ea_row17_col12, #T_f64ea_row23_col20, #T_f64ea_row46_col12, #T_f64ea_row47_col18 {
#   background-color: #1c396f;
#   color: #f1f1f1;
# }
# #T_f64ea_row0_col16, #T_f64ea_row0_col17, #T_f64ea_row0_col19, #T_f64ea_row0_col21, #T_f64ea_row1_col11, #T_f64ea_row1_col12, #T_f64ea_row1_col14, #T_f64ea_row1_col18, #T_f64ea_row2_col8, #T_f64ea_row2_col9, #T_f64ea_row2_col10, #T_f64ea_row4_col13, #T_f64ea_row8_col2, #T_f64ea_row8_col6, #T_f64ea_row12_col7, #T_f64ea_row15_col7, #T_f64ea_row22_col15, #T_f64ea_row30_col0, #T_f64ea_row43_col2, #T_f64ea_row43_col6, #T_f64ea_row43_col20, #T_f64ea_row47_col3, #T_f64ea_row47_col4, #T_f64ea_row47_col5 {
#   background-color: #fee838;
#   color: #000000;
# }
# #T_f64ea_row0_col18, #T_f64ea_row20_col10 {
#   background-color: #9f9775;
#   color: #f1f1f1;
# }
# #T_f64ea_row0_col20, #T_f64ea_row11_col16, #T_f64ea_row21_col12, #T_f64ea_row26_col4, #T_f64ea_row28_col10, #T_f64ea_row46_col9 {
#   background-color: #727374;
#   color: #f1f1f1;
# }
# #T_f64ea_row0_col22, #T_f64ea_row1_col22, #T_f64ea_row2_col22, #T_f64ea_row3_col22, #T_f64ea_row4_col22, #T_f64ea_row5_col22, #T_f64ea_row6_col22, #T_f64ea_row7_col22, #T_f64ea_row8_col22, #T_f64ea_row9_col22, #T_f64ea_row10_col22, #T_f64ea_row11_col22, #T_f64ea_row12_col22, #T_f64ea_row13_col22, #T_f64ea_row14_col22, #T_f64ea_row15_col22, #T_f64ea_row16_col22, #T_f64ea_row17_col22, #T_f64ea_row18_col22, #T_f64ea_row19_col22, #T_f64ea_row20_col22, #T_f64ea_row21_col22, #T_f64ea_row22_col22, #T_f64ea_row23_col22, #T_f64ea_row24_col22, #T_f64ea_row25_col22, #T_f64ea_row26_col22, #T_f64ea_row27_col22, #T_f64ea_row28_col22, #T_f64ea_row29_col22, #T_f64ea_row30_col22, #T_f64ea_row31_col22, #T_f64ea_row32_col22, #T_f64ea_row33_col22, #T_f64ea_row34_col22, #T_f64ea_row35_col22, #T_f64ea_row36_col22, #T_f64ea_row37_col22, #T_f64ea_row38_col22, #T_f64ea_row39_col22, #T_f64ea_row40_col22, #T_f64ea_row41_col22, #T_f64ea_row42_col22, #T_f64ea_row43_col22, #T_f64ea_row44_col22, #T_f64ea_row45_col22, #T_f64ea_row46_col22, #T_f64ea_row47_col22 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_f64ea_row1_col0, #T_f64ea_row4_col20, #T_f64ea_row9_col20, #T_f64ea_row40_col17, #T_f64ea_row40_col19, #T_f64ea_row46_col20 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_f64ea_row1_col3, #T_f64ea_row13_col20, #T_f64ea_row17_col20, #T_f64ea_row25_col19, #T_f64ea_row32_col17, #T_f64ea_row32_col20 {
#   background-color: #003171;
#   color: #f1f1f1;
# }
# #T_f64ea_row1_col4, #T_f64ea_row12_col11, #T_f64ea_row34_col0 {
#   background-color: #34456c;
#   color: #f1f1f1;
# }
# #T_f64ea_row1_col5, #T_f64ea_row9_col14, #T_f64ea_row11_col14, #T_f64ea_row14_col8, #T_f64ea_row14_col10, #T_f64ea_row14_col12, #T_f64ea_row19_col15, #T_f64ea_row39_col19 {
#   background-color: #0f3570;
#   color: #f1f1f1;
# }
# #T_f64ea_row1_col7 {
#   background-color: #f2da44;
#   color: #000000;
# }
# #T_f64ea_row1_col8 {
#   background-color: #d1bf61;
#   color: #000000;
# }
# #T_f64ea_row1_col9, #T_f64ea_row1_col10, #T_f64ea_row33_col2, #T_f64ea_row33_col6 {
#   background-color: #d0be62;
#   color: #000000;
# }
# #T_f64ea_row1_col13 {
#   background-color: #ebd44b;
#   color: #000000;
# }
# #T_f64ea_row1_col15, #T_f64ea_row9_col3, #T_f64ea_row14_col18, #T_f64ea_row18_col19, #T_f64ea_row27_col19, #T_f64ea_row34_col13 {
#   background-color: #2e416d;
#   color: #f1f1f1;
# }
# #T_f64ea_row1_col16, #T_f64ea_row8_col13, #T_f64ea_row29_col9 {
#   background-color: #828079;
#   color: #f1f1f1;
# }
# #T_f64ea_row1_col17, #T_f64ea_row9_col16, #T_f64ea_row17_col9, #T_f64ea_row24_col18 {
#   background-color: #a99f73;
#   color: #f1f1f1;
# }
# #T_f64ea_row1_col19, #T_f64ea_row13_col7, #T_f64ea_row31_col2, #T_f64ea_row31_col6, #T_f64ea_row33_col18, #T_f64ea_row33_col20, #T_f64ea_row40_col21 {
#   background-color: #aaa073;
#   color: #f1f1f1;
# }
# #T_f64ea_row1_col20, #T_f64ea_row6_col12, #T_f64ea_row11_col13, #T_f64ea_row11_col19, #T_f64ea_row12_col20, #T_f64ea_row18_col15, #T_f64ea_row29_col12, #T_f64ea_row37_col20, #T_f64ea_row38_col0, #T_f64ea_row39_col12, #T_f64ea_row39_col14, #T_f64ea_row43_col9 {
#   background-color: #233c6e;
#   color: #f1f1f1;
# }
# #T_f64ea_row1_col21, #T_f64ea_row2_col19, #T_f64ea_row3_col8, #T_f64ea_row3_col10, #T_f64ea_row7_col9, #T_f64ea_row21_col21, #T_f64ea_row33_col9, #T_f64ea_row45_col2, #T_f64ea_row45_col6 {
#   background-color: #7a7a78;
#   color: #f1f1f1;
# }
# #T_f64ea_row2_col0, #T_f64ea_row6_col2, #T_f64ea_row6_col6, #T_f64ea_row47_col0 {
#   background-color: #00234f;
#   color: #f1f1f1;
# }
# #T_f64ea_row2_col2, #T_f64ea_row2_col6, #T_f64ea_row14_col16, #T_f64ea_row24_col9, #T_f64ea_row27_col14, #T_f64ea_row36_col16, #T_f64ea_row43_col15 {
#   background-color: #3e4b6c;
#   color: #f1f1f1;
# }
# #T_f64ea_row2_col3, #T_f64ea_row7_col8, #T_f64ea_row7_col10, #T_f64ea_row33_col8, #T_f64ea_row36_col3, #T_f64ea_row37_col19 {
#   background-color: #60646f;
#   color: #f1f1f1;
# }
# #T_f64ea_row2_col4, #T_f64ea_row30_col15 {
#   background-color: #c5b568;
#   color: #000000;
# }
# #T_f64ea_row2_col5, #T_f64ea_row8_col21, #T_f64ea_row12_col5, #T_f64ea_row14_col5, #T_f64ea_row20_col4, #T_f64ea_row26_col9, #T_f64ea_row35_col12, #T_f64ea_row35_col15, #T_f64ea_row44_col12, #T_f64ea_row47_col2, #T_f64ea_row47_col6 {
#   background-color: #696b71;
#   color: #f1f1f1;
# }
# #T_f64ea_row2_col7, #T_f64ea_row23_col10, #T_f64ea_row25_col5, #T_f64ea_row33_col17, #T_f64ea_row38_col5 {
#   background-color: #777776;
#   color: #f1f1f1;
# }
# #T_f64ea_row2_col11, #T_f64ea_row16_col9, #T_f64ea_row16_col17, #T_f64ea_row21_col11, #T_f64ea_row22_col14, #T_f64ea_row25_col13, #T_f64ea_row27_col11, #T_f64ea_row30_col19, #T_f64ea_row43_col19 {
#   background-color: #4d556c;
